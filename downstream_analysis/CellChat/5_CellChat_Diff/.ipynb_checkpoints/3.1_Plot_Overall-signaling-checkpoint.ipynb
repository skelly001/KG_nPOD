# %% [markdown]
# # Settings

# %%
options(scipen=999)
pacman::p_load(dplyr, stringr, data.table, tidyr, plyr,
               pheatmap, colorRamps, gridExtra, ggplot2, ggrepel, RColorBrewer,ComplexHeatmap,vioplot,ggforce)

# %% [markdown]
# ## Directories

# %%
# Set working directories
base.dir =  "/nfs/lab/projects/CellCrosstalk/npod.pancreas/Final/"
assets.dir = paste(base.dir, "Assets/", sep = "") 
results.dir = paste(base.dir, "Results/corrected/", sep = "")
permutation.result.dir = paste(base.dir, "Results/corrected.permutation.test/", sep = "")


# Databases
cc.db = "/nfs/lab/projects/islet_multiomics_stress/analysis/CellChat/Assets/CellChatDB.human.txt"
Gaulton.db.dir = "/nfs/lab/Luca/Assets/LR.Database/GaultonDB_V2.txt"

permutations.test.tmp.dir = paste(permutation.result.dir, "TMP/", sep = "")
permutations.test.res.dir = paste(permutation.result.dir, "Results/", sep = "")

cc.db = "/nfs/lab/projects/islet_multiomics_stress/analysis/CellChat/Assets/CellChatDB.human.txt"

# %% [markdown]
# ## Variables

# %%
# conditions
condition.ls = c("ND", "Aab", "T1D_early","T1D_late")

colors.conditions = c("ND" = "#85EF1B",
                      "Aab" = "#EFEF1B",
                      "T1D_early" = "#EF851B",
                      "T1D_late" = "#EF1B1B")

# Contrasts
Contrast_1 = c(condition.ls[2], condition.ls[3], condition.ls[4])
Contrast_2 = c(condition.ls[1], condition.ls[1], condition.ls[1])

# Celltypes and compartments
Endocrine = c('Alpha', 'Beta', 'Delta')
Exocrine = c('Acinar1_2_6','Acinar_3','Acinar_4','Acinar_5','Ductal','MUC5b_Ductal')
Immune = c('Tcells','Macrophage')
Endothelial = c('Endothelial')
Stromal = c('Activated_Stellate','Quiescent_Stellate')

cell.pop.order = c(Endocrine, Exocrine, Immune, Endothelial, Stromal)
rev.cell.pop.order = c(rev(Stromal), rev(Endothelial), rev(Immune), rev(Exocrine), rev(Endocrine), use.names = TRUE)

compartment = cell.pop.order
compartment = ifelse(compartment  %in%  Endocrine, "Endocrine", 
                 ifelse(compartment  %in%  Exocrine, "Exocrine",
                        ifelse(compartment  %in%  Immune, "Immune",
                               ifelse(compartment  %in%  Endothelial, "Endothelial", "Stromal"))))

Cellpop.compartment = as.data.frame(cbind(cell.pop.order, compartment))
Cellpop.compartment$compartment = factor(Cellpop.compartment$compartment, levels = c('Endocrine','Exocrine','Immune','Endothelial', "Stromal"))
colnames(Cellpop.compartment)[1] = "Celltype"

colors.compartments = c('Endocrine'='#26bfbf',
           'Exocrine'='#ed872d',
           'Immune'='#3F98E0',
           'Endothelial'='#800080',
           'Stromal'='#F5DE6C')

Cellpop.compartment$colors.compartments = compartment
Cellpop.compartment$colors.compartments = mapvalues(Cellpop.compartment$colors.compartments, names(colors.compartments), colors.compartments, warn_missing = TRUE)
gaps.compartments = c(3, 9, 11, 12)

# %% [markdown]
# # Permutation test

# %% [markdown]
# ## Observations

# %%
LR.data.consensus.sig.thresh = read.table(paste(results.dir,
                                               "LR.data.consensus.sig.thresh.txt", sep = ""),
                                          sep = "\t", stringsAsFactors = F, header = T)
LR.data.consensus.sig.thresh = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$target %in% cell.pop.order, ]
LR.data.consensus.sig.thresh = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$source %in% cell.pop.order, ]

# %%
# Split LR pairs
LR.data.ND = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$condition == condition.ls[1], ]
LR.data.AAB = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$condition == condition.ls[2], ]
LR.data.ETD = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$condition == condition.ls[3], ]
LR.data.LTD = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$condition == condition.ls[4], ]
nrow(LR.data.consensus.sig.thresh)
# Print stats
message("LR pairs in ND: ", nrow(LR.data.ND))
message("LR pairs in AAB : ", nrow(LR.data.AAB))
message("LR pairs in Early T1D: ", nrow(LR.data.ETD))
message("LR pairs in Late T1D: ", nrow(LR.data.LTD))
# Out:
# [1] 87650
# LR pairs in ND: 27139
#
# LR pairs in AAB : 27459
#
# LR pairs in Early T1D: 18179
#
# LR pairs in Late T1D: 14873

# %%
head(LR.data.consensus.sig.thresh, n=1)
# Out:
#   ligand  source target             receptor  prob          pval
# 1 ADCYAP1 Beta   Quiescent_Stellate ADCYAP1R1 0.00006164112 0.0001
#   interaction_name  interaction_name_2  pathway_name annotation         ⋯
# 1 ADCYAP1_ADCYAP1R1 ADCYAP1 - ADCYAP1R1 PACAP        Secreted Signaling ⋯
#   FDR         interaction.id                               compartment.source
# 1 0.000153715 Beta--Quiescent_Stellate--ADCYAP1--ADCYAP1R1 Endocrine
#   compartment.target Type   Mode.of.Action     Signaling
# 1 Stromal            Ligand Secreted Signaling Hormones & Neuropeptides
#   Functional.classification Functional.sub.classification Gene.Family
# 1 Hormone/Neuropeptide      Other                         PACAP Family

# %%
condition.sizes = c(nrow(LR.data.ND), nrow(LR.data.AAB), nrow(LR.data.ETD), nrow(LR.data.LTD))
names(condition.sizes) = condition.ls
condition.sizes
condition.size_1 = c(condition.sizes[2], condition.sizes[3], condition.sizes[4])
condition.size_2 = c(condition.sizes[1], condition.sizes[1], condition.sizes[1])
# Out:
#        ND       Aab T1D_early  T1D_late
#     27139     27459     18179     14873

# %%
# Aggregate interactions
LR.ND = aggregate(LR.data.ND$prob, by=list(condition=LR.data.ND$condition),FUN=sum)
colnames(LR.ND)[2] = "IS"
LR.AAB = aggregate(LR.data.AAB$prob, by=list(condition=LR.data.AAB$condition),FUN=sum)
colnames(LR.AAB)[2] = "IS"
LR.ETD = aggregate(LR.data.ETD$prob, by=list(condition=LR.data.ETD$condition),FUN=sum)
colnames(LR.ETD)[2] = "IS"
LR.LTD = aggregate(LR.data.LTD$prob, by=list(condition=LR.data.LTD$condition),FUN=sum)
colnames(LR.LTD)[2] = "IS"
stat.data = rbind(LR.ND, LR.AAB, LR.ETD, LR.LTD)
stat.data$condition = factor(stat.data$condition, levels = rev(condition.ls))
# Count interactions
Interaction.number = as.data.frame(table(LR.data.consensus.sig.thresh$condition))
colnames(Interaction.number)[1] = "condition"
Interaction.number$condition = factor(Interaction.number$condition, levels = rev(condition.ls))
# Merge
stat.data = merge(stat.data, Interaction.number, by = "condition")
stat.data$average.IS = stat.data$IS/stat.data$Freq

# %%
diff.obs = list()
abs.diff.obs = list()
count.diff.obs = list()
count.abs.diff.obs = list()
avg.diff.obs = list()
avg.abs.diff.obs = list()

for (i in seq_along(Contrast_1)){
    # Subset to target cell
    LR.data.use <- LR.data.consensus.sig.thresh
    # Subset for the contrast
    contrast = c(Contrast_1[i], Contrast_2[i])
    message("Processing ", Contrast_1[i], " vs ", Contrast_2[i])
    LR.data.c1 = LR.data.use[LR.data.use$condition %in% contrast[1], ]
    LR.data.c2 = LR.data.use[LR.data.use$condition %in% contrast[2], ]
    message("Distribution of interactions in contrast: \n",
            Contrast_1[i], ": ", nrow(LR.data.c1), "\n",
            Contrast_2[i], ": ", nrow(LR.data.c2))
    # Replace NA with 0
    LR.data.c1$prob[is.na(LR.data.c1$prob)] = 0
    LR.data.c2$prob[is.na(LR.data.c2$prob)] = 0
    
    # Aggregate interactions
    LR.data.c1.agr <- sum(LR.data.c1[, 'prob'])
    LR.data.c2.agr <- sum(LR.data.c2[, 'prob'])
    # Compute difference
    diff.obs[[i]] = LR.data.c1.agr - LR.data.c2.agr
    names(diff.obs[[i]]) = Contrast_1[i]
    abs.diff.obs[[i]] = abs(diff.obs[[i]])
   
    # count all interctions
    LR.data.c1.count <- nrow(LR.data.c1)
    LR.data.c2.count <- nrow(LR.data.c2)
    # Compute difference
    count.diff.obs[[i]] = LR.data.c1.count - LR.data.c2.count
    names(count.diff.obs[[i]]) = Contrast_1[i]
    count.abs.diff.obs[[i]] = abs(count.diff.obs[[i]])
    
    # average IS
    LR.data.c1.avg <- LR.data.c1.agr/LR.data.c1.count
    LR.data.c2.avg <- LR.data.c2.agr/LR.data.c2.count
    # Compute difference
    avg.diff.obs[[i]] = LR.data.c1.avg - LR.data.c2.avg
    names(avg.diff.obs[[i]]) = Contrast_1[i]
    avg.abs.diff.obs[[i]] = abs(avg.diff.obs[[i]])
}
# Out:
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27459
# ND: 27139
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 18179
# ND: 27139
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 14873
# ND: 27139

# %%
diff.obs
count.diff.obs
avg.diff.obs

abs.diff.obs
count.abs.diff.obs
avg.abs.diff.obs
# Out:
# [[1]]
#        Aab
# -0.2252866
#
# [[2]]
# T1D_early
# -4.321782
#
# [[3]]
#  T1D_late
# -14.30152
# [[1]]
# Aab
# 320
#
# [[2]]
# T1D_early
#     -8960
#
# [[3]]
# T1D_late
#   -12266
# [[1]]
#            Aab
# -0.00002563633
#
# [[2]]
#   T1D_early
# 0.000499518
#
# [[3]]
#    T1D_late
# 0.000272048
# [[1]]
#       Aab
# 0.2252866
#
# [[2]]
# T1D_early
#  4.321782
#
# [[3]]
# T1D_late
# 14.30152
# [[1]]
# Aab
# 320
#
# [[2]]
# T1D_early
#      8960
#
# [[3]]
# T1D_late
#    12266
# [[1]]
#           Aab
# 0.00002563633
#
# [[2]]
#   T1D_early
# 0.000499518
#
# [[3]]
#    T1D_late
# 0.000272048

# %% [markdown]
# ## Simulations

# %%
nsim = 100

# %%
setwd(permutations.test.tmp.dir)
stars = NULL
stars.count = NULL
stars.avg = NULL

for (i in seq_along(Contrast_1)){
    # Get files
    sim.list <- dir(pattern = "_DFnet.txt")
    diff.sim.data = NULL
    abs.diff.sim.data = NULL
    count.diff.sim.data = NULL
    abs.count.diff.sim.data = NULL
    avg.diff.sim.data = NULL
    abs.avg.diff.sim.data = NULL
    for (s.i in seq_along(sim.list)){
        message("Processing: ", sim.list[s.i])
        # Load simulation data
        LR.data.use <- read.table(sim.list[s.i], sep = "\t", stringsAsFactors = F, header = T)
        message("\t Detected: ", nrow(LR.data.use), " interactions")
        # Subset for the contrast
        contrast = c(Contrast_1[i], Contrast_2[i])
        message("Processing ", Contrast_1[i], " vs ", Contrast_2[i])
        LR.data.c1 = LR.data.use[LR.data.use$condition %in% contrast[1], ]
        LR.data.c2 = LR.data.use[LR.data.use$condition %in% contrast[2], ]
        message("Distribution of interactions in contrast: \n",
                Contrast_1[i], ": ", nrow(LR.data.c1), "\n",
                Contrast_2[i], ": ", nrow(LR.data.c2))
        # Replace NA with 0
        LR.data.c1$prob[is.na(LR.data.c1$prob)] = 0
        LR.data.c2$prob[is.na(LR.data.c2$prob)] = 0

        # Aggregate interactions
        LR.data.c1.agr <- sum(LR.data.c1[, 'prob'])
        LR.data.c2.agr <- sum(LR.data.c2[, 'prob'])
        # Compute difference
        diff.sim = LR.data.c1.agr - LR.data.c2.agr
        names(diff.sim) = Contrast_1[i]
        abs.diff.sim = abs(diff.sim)
        # pile up results
        diff.sim.data = cbind(diff.sim.data, diff.sim)
        colnames(diff.sim.data)[ncol(diff.sim.data)] = s.i
        abs.diff.sim.data = cbind(abs.diff.sim.data, abs.diff.sim)
        colnames(abs.diff.sim.data)[ncol(abs.diff.sim.data)] = s.i
        
        # count all interctions
        LR.data.c1.count <- nrow(LR.data.c1)
        LR.data.c2.count <- nrow(LR.data.c2)
        # Compute difference
        count.diff.sim = LR.data.c1.count - LR.data.c2.count
        names(count.diff.sim) = Contrast_1[i]
        abs.count.diff.sim = abs(count.diff.sim)
        # pile up results
        count.diff.sim.data = cbind(count.diff.sim.data, count.diff.sim)
        colnames(count.diff.sim.data)[ncol(count.diff.sim.data)] = s.i
        abs.count.diff.sim.data = cbind(abs.count.diff.sim.data, abs.count.diff.sim)
        colnames(abs.count.diff.sim.data)[ncol(abs.count.diff.sim.data)] = s.i
        
        # average IS
        LR.data.c1.avg <- LR.data.c1.agr/LR.data.c1.count
        LR.data.c2.avg <- LR.data.c2.agr/LR.data.c2.count
        # Compute difference
        avg.diff.sim = LR.data.c1.avg - LR.data.c2.avg
        names(avg.diff.sim) = Contrast_1[i]
        abs.avg.diff.sim = abs(avg.diff.sim)
        # pile up results
        avg.diff.sim.data = cbind(avg.diff.sim.data, avg.diff.sim)
        colnames(avg.diff.sim.data)[ncol(avg.diff.sim.data)] = s.i
        abs.avg.diff.sim.data = cbind(abs.avg.diff.sim.data, abs.avg.diff.sim)
        colnames(abs.avg.diff.sim.data)[ncol(abs.avg.diff.sim.data)] = s.i
        
    }
    ## count how many times, per row, simulated is > real
    random.success.table = abs.diff.sim.data > abs.diff.obs[[i]]
    random.success = rowSums(random.success.table == "TRUE", na.rm = TRUE)
    pvalue = random.success/nsim
    ## Modify pvalue of results that had observed difference = 0 
    pvalue = replace(pvalue, diff.obs[[i]] == 0, 1)
    # Make dataframe for stars
    stars.tpm = pvalue
    stars.tpm[pvalue>0.05]<-""
    stars.tpm[pvalue<=0.05]<-"*"
    stars.tpm[pvalue<=0.01]<-"**"
    stars.tpm[pvalue==0]<-"***"
    stars.tpm = data.frame(stars = stars.tpm)
    stars.tpm$pvalue = pvalue
    stars.tpm$condition = Contrast_1[i]
    stars = rbind(stars, stars.tpm)
    
    file.name = paste(permutations.test.res.dir, "Permutation.test_IS_Across_conditions.res", sep = "")
    write.table(stars, file.name, sep = "\t", quote = F, col.names=T, row.names = T)
    
    ## count how many times, per row, simulated is > real
    random.success.table = abs.count.diff.sim.data > count.abs.diff.obs[[i]]
    random.success = rowSums(random.success.table == "TRUE", na.rm = TRUE)
    pvalue = random.success/nsim
    ## Modify pvalue of results that had observed difference = 0 
    pvalue = replace(pvalue, count.diff.obs[[i]] == 0, 1)
    # Make dataframe for stars
    stars.tpm = pvalue
    stars.tpm[pvalue>0.05]<-""
    stars.tpm[pvalue<=0.05]<-"*"
    stars.tpm[pvalue<=0.01]<-"**"
    stars.tpm[pvalue==0]<-"***"
    stars.tpm = data.frame(stars = stars.tpm)
    stars.tpm$pvalue = pvalue
    stars.tpm$condition = Contrast_1[i]
    stars.count = rbind(stars.count, stars.tpm)
    
    file.name = paste(permutations.test.res.dir, "Permutation.test_counts_Across_conditions.res", sep = "")
    write.table(stars.count, file.name, sep = "\t", quote = F, col.names=T, row.names = T)
    
    ## count how many times, per row, simulated is > real
    random.success.table = abs.avg.diff.sim.data > avg.abs.diff.obs[[i]]
    random.success = rowSums(random.success.table == "TRUE", na.rm = TRUE)
    pvalue = random.success/nsim
    
    ## Modify pvalue of results that had observed difference = 0 
    pvalue = replace(pvalue, avg.diff.obs[[i]] == 0, 1)
    # Make dataframe for stars
    stars.tpm = pvalue
    stars.tpm[pvalue>0.05]<-""
    stars.tpm[pvalue<=0.05]<-"*"
    stars.tpm[pvalue<=0.01]<-"**"
    stars.tpm[pvalue==0]<-"***"
    stars.tpm = data.frame(stars = stars.tpm)
    stars.tpm$pvalue = pvalue
    stars.tpm$condition = Contrast_1[i]
    stars.avg = rbind(stars.avg, stars.tpm)
    
    file.name = paste(permutations.test.res.dir, "Permutation.test_avg_Across_conditions.res", sep = "")
    write.table(stars.avg, file.name, sep = "\t", quote = F, col.names=T, row.names = T) 
}
# Out:
# Processing: CellChat_Permutation_n1_DFnet.txt
#
# 	 Detected: 99555 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27464
# ND: 22024
#
# Processing: CellChat_Permutation_n10_DFnet.txt
#
# 	 Detected: 100481 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25931
# ND: 27308
#
# Processing: CellChat_Permutation_n100_DFnet.txt
#
# 	 Detected: 100445 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23908
# ND: 26766
#
# Processing: CellChat_Permutation_n11_DFnet.txt
#
# 	 Detected: 100219 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25876
# ND: 27789
#
# Processing: CellChat_Permutation_n12_DFnet.txt
#
# 	 Detected: 99242 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27019
# ND: 23929
#
# Processing: CellChat_Permutation_n13_DFnet.txt
#
# 	 Detected: 101105 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26003
# ND: 26148
#
# Processing: CellChat_Permutation_n14_DFnet.txt
#
# 	 Detected: 100237 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26469
# ND: 25855
#
# Processing: CellChat_Permutation_n15_DFnet.txt
#
# 	 Detected: 100698 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25118
# ND: 25895
#
# Processing: CellChat_Permutation_n16_DFnet.txt
#
# 	 Detected: 97143 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25016
# ND: 25371
#
# Processing: CellChat_Permutation_n17_DFnet.txt
#
# 	 Detected: 98694 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27118
# ND: 23164
#
# Processing: CellChat_Permutation_n18_DFnet.txt
#
# 	 Detected: 101439 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23523
# ND: 26595
#
# Processing: CellChat_Permutation_n19_DFnet.txt
#
# 	 Detected: 95333 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23083
# ND: 27225
#
# Processing: CellChat_Permutation_n2_DFnet.txt
#
# 	 Detected: 99776 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 28011
# ND: 26370
#
# Processing: CellChat_Permutation_n20_DFnet.txt
#
# 	 Detected: 99410 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 20706
# ND: 25752
#
# Processing: CellChat_Permutation_n21_DFnet.txt
#
# 	 Detected: 98542 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27400
# ND: 26450
#
# Processing: CellChat_Permutation_n22_DFnet.txt
#
# 	 Detected: 101611 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25551
# ND: 25579
#
# Processing: CellChat_Permutation_n23_DFnet.txt
#
# 	 Detected: 99234 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 22500
# ND: 24284
#
# Processing: CellChat_Permutation_n24_DFnet.txt
#
# 	 Detected: 97421 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26106
# ND: 27299
#
# Processing: CellChat_Permutation_n25_DFnet.txt
#
# 	 Detected: 98194 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23127
# ND: 27026
#
# Processing: CellChat_Permutation_n26_DFnet.txt
#
# 	 Detected: 100473 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24414
# ND: 27765
#
# Processing: CellChat_Permutation_n27_DFnet.txt
#
# 	 Detected: 98902 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26230
# ND: 26838
#
# Processing: CellChat_Permutation_n28_DFnet.txt
#
# 	 Detected: 101535 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26003
# ND: 24622
#
# Processing: CellChat_Permutation_n29_DFnet.txt
#
# 	 Detected: 101741 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26889
# ND: 22634
#
# Processing: CellChat_Permutation_n3_DFnet.txt
#
# 	 Detected: 100497 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24988
# ND: 22418
#
# Processing: CellChat_Permutation_n30_DFnet.txt
#
# 	 Detected: 99336 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 22784
# ND: 25698
#
# Processing: CellChat_Permutation_n31_DFnet.txt
#
# 	 Detected: 99931 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23129
# ND: 25476
#
# Processing: CellChat_Permutation_n32_DFnet.txt
#
# 	 Detected: 101785 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26595
# ND: 24870
#
# Processing: CellChat_Permutation_n33_DFnet.txt
#
# 	 Detected: 95037 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 21540
# ND: 28040
#
# Processing: CellChat_Permutation_n34_DFnet.txt
#
# 	 Detected: 95209 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24844
# ND: 26980
#
# Processing: CellChat_Permutation_n35_DFnet.txt
#
# 	 Detected: 100241 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26661
# ND: 24683
#
# Processing: CellChat_Permutation_n36_DFnet.txt
#
# 	 Detected: 99566 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26498
# ND: 26154
#
# Processing: CellChat_Permutation_n37_DFnet.txt
#
# 	 Detected: 100189 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25380
# ND: 26920
#
# Processing: CellChat_Permutation_n38_DFnet.txt
#
# 	 Detected: 101897 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27538
# ND: 24536
#
# Processing: CellChat_Permutation_n39_DFnet.txt
#
# 	 Detected: 100816 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27519
# ND: 25575
#
# Processing: CellChat_Permutation_n4_DFnet.txt
#
# 	 Detected: 98506 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25896
# ND: 25958
#
# Processing: CellChat_Permutation_n40_DFnet.txt
#
# 	 Detected: 101030 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26196
# ND: 25146
#
# Processing: CellChat_Permutation_n41_DFnet.txt
#
# 	 Detected: 100533 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25094
# ND: 26802
#
# Processing: CellChat_Permutation_n42_DFnet.txt
#
# 	 Detected: 101489 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26373
# ND: 27018
#
# Processing: CellChat_Permutation_n43_DFnet.txt
#
# 	 Detected: 99807 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27643
# ND: 22925
#
# Processing: CellChat_Permutation_n44_DFnet.txt
#
# 	 Detected: 97447 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 20494
# ND: 27012
#
# Processing: CellChat_Permutation_n45_DFnet.txt
#
# 	 Detected: 100370 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25875
# ND: 23792
#
# Processing: CellChat_Permutation_n46_DFnet.txt
#
# 	 Detected: 98702 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25468
# ND: 25907
#
# Processing: CellChat_Permutation_n47_DFnet.txt
#
# 	 Detected: 99726 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26800
# ND: 25710
#
# Processing: CellChat_Permutation_n48_DFnet.txt
#
# 	 Detected: 97819 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 18984
# ND: 26628
#
# Processing: CellChat_Permutation_n49_DFnet.txt
#
# 	 Detected: 98560 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 22306
# ND: 24813
#
# Processing: CellChat_Permutation_n5_DFnet.txt
#
# 	 Detected: 97817 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23678
# ND: 25243
#
# Processing: CellChat_Permutation_n50_DFnet.txt
#
# 	 Detected: 98716 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25446
# ND: 25541
#
# Processing: CellChat_Permutation_n51_DFnet.txt
#
# 	 Detected: 100975 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24723
# ND: 25498
#
# Processing: CellChat_Permutation_n52_DFnet.txt
#
# 	 Detected: 101413 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 22704
# ND: 25673
# Processing: CellChat_Permutation_n53_DFnet.txt
#
# 	 Detected: 101679 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 28080
# ND: 23941
#
# Processing: CellChat_Permutation_n54_DFnet.txt
#
# 	 Detected: 100150 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24098
# ND: 26891
#
# Processing: CellChat_Permutation_n55_DFnet.txt
#
# 	 Detected: 99520 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25930
# ND: 22541
#
# Processing: CellChat_Permutation_n56_DFnet.txt
#
# 	 Detected: 99871 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23839
# ND: 27936
#
# Processing: CellChat_Permutation_n57_DFnet.txt
#
# 	 Detected: 100675 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25396
# ND: 23482
#
# Processing: CellChat_Permutation_n58_DFnet.txt
#
# 	 Detected: 97855 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23474
# ND: 27379
#
# Processing: CellChat_Permutation_n59_DFnet.txt
#
# 	 Detected: 101343 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27514
# ND: 25600
#
# Processing: CellChat_Permutation_n6_DFnet.txt
#
# 	 Detected: 99051 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24380
# ND: 25618
#
# Processing: CellChat_Permutation_n60_DFnet.txt
#
# 	 Detected: 100267 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23505
# ND: 25062
#
# Processing: CellChat_Permutation_n61_DFnet.txt
#
# 	 Detected: 101286 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26823
# ND: 26430
#
# Processing: CellChat_Permutation_n62_DFnet.txt
#
# 	 Detected: 96315 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24418
# ND: 28467
#
# Processing: CellChat_Permutation_n63_DFnet.txt
#
# 	 Detected: 100624 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25735
# ND: 25017
#
# Processing: CellChat_Permutation_n64_DFnet.txt
#
# 	 Detected: 99191 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 21042
# ND: 26930
#
# Processing: CellChat_Permutation_n65_DFnet.txt
#
# 	 Detected: 98729 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25944
# ND: 27104
#
# Processing: CellChat_Permutation_n66_DFnet.txt
#
# 	 Detected: 102149 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26514
# ND: 24828
#
# Processing: CellChat_Permutation_n67_DFnet.txt
#
# 	 Detected: 98906 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24952
# ND: 25475
#
# Processing: CellChat_Permutation_n68_DFnet.txt
#
# 	 Detected: 101909 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24926
# ND: 25797
#
# Processing: CellChat_Permutation_n69_DFnet.txt
#
# 	 Detected: 101547 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26755
# ND: 24423
#
# Processing: CellChat_Permutation_n7_DFnet.txt
#
# 	 Detected: 100376 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25243
# ND: 28613
#
# Processing: CellChat_Permutation_n70_DFnet.txt
#
# 	 Detected: 96512 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 19641
# ND: 24618
#
# Processing: CellChat_Permutation_n71_DFnet.txt
#
# 	 Detected: 101467 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27132
# ND: 26125
#
# Processing: CellChat_Permutation_n72_DFnet.txt
#
# 	 Detected: 97608 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25919
# ND: 22174
#
# Processing: CellChat_Permutation_n73_DFnet.txt
#
# 	 Detected: 100827 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25693
# ND: 25592
#
# Processing: CellChat_Permutation_n74_DFnet.txt
#
# 	 Detected: 99517 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25570
# ND: 26015
#
# Processing: CellChat_Permutation_n75_DFnet.txt
#
# 	 Detected: 100971 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24220
# ND: 24778
#
# Processing: CellChat_Permutation_n76_DFnet.txt
#
# 	 Detected: 99108 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27089
# ND: 26175
#
# Processing: CellChat_Permutation_n77_DFnet.txt
#
# 	 Detected: 94929 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 17962
# ND: 27014
#
# Processing: CellChat_Permutation_n78_DFnet.txt
#
# 	 Detected: 100961 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24468
# ND: 27366
#
# Processing: CellChat_Permutation_n79_DFnet.txt
#
# 	 Detected: 97093 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 20481
# ND: 26896
#
# Processing: CellChat_Permutation_n8_DFnet.txt
#
# 	 Detected: 100816 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26709
# ND: 25420
#
# Processing: CellChat_Permutation_n80_DFnet.txt
#
# 	 Detected: 99724 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23382
# ND: 24852
#
# Processing: CellChat_Permutation_n81_DFnet.txt
#
# 	 Detected: 97718 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23397
# ND: 29352
#
# Processing: CellChat_Permutation_n82_DFnet.txt
#
# 	 Detected: 98372 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 21088
# ND: 26790
#
# Processing: CellChat_Permutation_n83_DFnet.txt
#
# 	 Detected: 97713 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25491
# ND: 26239
#
# Processing: CellChat_Permutation_n84_DFnet.txt
#
# 	 Detected: 99042 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 22378
# ND: 26942
#
# Processing: CellChat_Permutation_n85_DFnet.txt
#
# 	 Detected: 97661 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24463
# ND: 27211
#
# Processing: CellChat_Permutation_n86_DFnet.txt
#
# 	 Detected: 99807 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 22224
# ND: 25724
#
# Processing: CellChat_Permutation_n87_DFnet.txt
#
# 	 Detected: 96966 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23069
# ND: 26195
#
# Processing: CellChat_Permutation_n88_DFnet.txt
#
# 	 Detected: 100825 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26855
# ND: 27382
#
# Processing: CellChat_Permutation_n89_DFnet.txt
#
# 	 Detected: 100253 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26304
# ND: 22683
#
# Processing: CellChat_Permutation_n9_DFnet.txt
#
# 	 Detected: 99613 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 23547
# ND: 26537
#
# Processing: CellChat_Permutation_n90_DFnet.txt
#
# 	 Detected: 99902 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26889
# ND: 24885
#
# Processing: CellChat_Permutation_n91_DFnet.txt
#
# 	 Detected: 101179 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24853
# ND: 23285
#
# Processing: CellChat_Permutation_n92_DFnet.txt
#
# 	 Detected: 97206 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25286
# ND: 20237
#
# Processing: CellChat_Permutation_n93_DFnet.txt
#
# 	 Detected: 96878 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 25088
# ND: 28296
#
# Processing: CellChat_Permutation_n94_DFnet.txt
#
# 	 Detected: 101228 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26970
# ND: 24566
#
# Processing: CellChat_Permutation_n95_DFnet.txt
#
# 	 Detected: 99354 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26586
# ND: 24638
#
# Processing: CellChat_Permutation_n96_DFnet.txt
#
# 	 Detected: 100904 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 27120
# ND: 24785
#
# Processing: CellChat_Permutation_n97_DFnet.txt
#
# 	 Detected: 100999 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 26576
# ND: 25650
# Processing: CellChat_Permutation_n98_DFnet.txt
#
# 	 Detected: 99113 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24931
# ND: 27409
#
# Processing: CellChat_Permutation_n99_DFnet.txt
#
# 	 Detected: 100786 interactions
#
# Processing Aab vs ND
#
# Distribution of interactions in contrast:
# Aab: 24313
# ND: 28311
#
# Processing: CellChat_Permutation_n1_DFnet.txt
#
# 	 Detected: 99555 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26560
# ND: 22024
#
# Processing: CellChat_Permutation_n10_DFnet.txt
#
# 	 Detected: 100481 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23769
# ND: 27308
#
# Processing: CellChat_Permutation_n100_DFnet.txt
#
# 	 Detected: 100445 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23688
# ND: 26766
#
# Processing: CellChat_Permutation_n11_DFnet.txt
#
# 	 Detected: 100219 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22580
# ND: 27789
#
# Processing: CellChat_Permutation_n12_DFnet.txt
#
# 	 Detected: 99242 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24361
# ND: 23929
#
# Processing: CellChat_Permutation_n13_DFnet.txt
#
# 	 Detected: 101105 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25616
# ND: 26148
#
# Processing: CellChat_Permutation_n14_DFnet.txt
#
# 	 Detected: 100237 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23464
# ND: 25855
#
# Processing: CellChat_Permutation_n15_DFnet.txt
#
# 	 Detected: 100698 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22387
# ND: 25895
#
# Processing: CellChat_Permutation_n16_DFnet.txt
#
# 	 Detected: 97143 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19372
# ND: 25371
#
# Processing: CellChat_Permutation_n17_DFnet.txt
#
# 	 Detected: 98694 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24999
# ND: 23164
#
# Processing: CellChat_Permutation_n18_DFnet.txt
#
# 	 Detected: 101439 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 27079
# ND: 26595
#
# Processing: CellChat_Permutation_n19_DFnet.txt
#
# 	 Detected: 95333 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19549
# ND: 27225
#
# Processing: CellChat_Permutation_n2_DFnet.txt
#
# 	 Detected: 99776 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 20596
# ND: 26370
#
# Processing: CellChat_Permutation_n20_DFnet.txt
#
# 	 Detected: 99410 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 27827
# ND: 25752
#
# Processing: CellChat_Permutation_n21_DFnet.txt
#
# 	 Detected: 98542 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19973
# ND: 26450
#
# Processing: CellChat_Permutation_n22_DFnet.txt
#
# 	 Detected: 101611 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26262
# ND: 25579
#
# Processing: CellChat_Permutation_n23_DFnet.txt
#
# 	 Detected: 99234 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26974
# ND: 24284
#
# Processing: CellChat_Permutation_n24_DFnet.txt
#
# 	 Detected: 97421 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19571
# ND: 27299
#
# Processing: CellChat_Permutation_n25_DFnet.txt
#
# 	 Detected: 98194 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22780
# ND: 27026
#
# Processing: CellChat_Permutation_n26_DFnet.txt
#
# 	 Detected: 100473 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24951
# ND: 27765
#
# Processing: CellChat_Permutation_n27_DFnet.txt
#
# 	 Detected: 98902 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21820
# ND: 26838
#
# Processing: CellChat_Permutation_n28_DFnet.txt
#
# 	 Detected: 101535 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25203
# ND: 24622
#
# Processing: CellChat_Permutation_n29_DFnet.txt
#
# 	 Detected: 101741 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26981
# ND: 22634
#
# Processing: CellChat_Permutation_n3_DFnet.txt
#
# 	 Detected: 100497 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25680
# ND: 22418
#
# Processing: CellChat_Permutation_n30_DFnet.txt
#
# 	 Detected: 99336 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22741
# ND: 25698
#
# Processing: CellChat_Permutation_n31_DFnet.txt
#
# 	 Detected: 99931 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25474
# ND: 25476
#
# Processing: CellChat_Permutation_n32_DFnet.txt
#
# 	 Detected: 101785 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25651
# ND: 24870
#
# Processing: CellChat_Permutation_n33_DFnet.txt
#
# 	 Detected: 95037 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19866
# ND: 28040
#
# Processing: CellChat_Permutation_n34_DFnet.txt
#
# 	 Detected: 95209 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 18619
# ND: 26980
#
# Processing: CellChat_Permutation_n35_DFnet.txt
#
# 	 Detected: 100241 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22803
# ND: 24683
#
# Processing: CellChat_Permutation_n36_DFnet.txt
#
# 	 Detected: 99566 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 20492
# ND: 26154
#
# Processing: CellChat_Permutation_n37_DFnet.txt
#
# 	 Detected: 100189 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24388
# ND: 26920
#
# Processing: CellChat_Permutation_n38_DFnet.txt
#
# 	 Detected: 101897 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25023
# ND: 24536
#
# Processing: CellChat_Permutation_n39_DFnet.txt
#
# 	 Detected: 100816 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23156
# ND: 25575
#
# Processing: CellChat_Permutation_n4_DFnet.txt
#
# 	 Detected: 98506 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22435
# ND: 25958
#
# Processing: CellChat_Permutation_n40_DFnet.txt
#
# 	 Detected: 101030 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23910
# ND: 25146
#
# Processing: CellChat_Permutation_n41_DFnet.txt
#
# 	 Detected: 100533 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23778
# ND: 26802
#
# Processing: CellChat_Permutation_n42_DFnet.txt
#
# 	 Detected: 101489 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24123
# ND: 27018
#
# Processing: CellChat_Permutation_n43_DFnet.txt
#
# 	 Detected: 99807 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25503
# ND: 22925
#
# Processing: CellChat_Permutation_n44_DFnet.txt
#
# 	 Detected: 97447 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23201
# ND: 27012
#
# Processing: CellChat_Permutation_n45_DFnet.txt
#
# 	 Detected: 100370 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23096
# ND: 23792
#
# Processing: CellChat_Permutation_n46_DFnet.txt
#
# 	 Detected: 98702 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21072
# ND: 25907
#
# Processing: CellChat_Permutation_n47_DFnet.txt
#
# 	 Detected: 99726 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 20832
# ND: 25710
#
# Processing: CellChat_Permutation_n48_DFnet.txt
#
# 	 Detected: 97819 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25513
# ND: 26628
# Processing: CellChat_Permutation_n49_DFnet.txt
#
# 	 Detected: 98560 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26502
# ND: 24813
#
# Processing: CellChat_Permutation_n5_DFnet.txt
#
# 	 Detected: 97817 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 20217
# ND: 25243
#
# Processing: CellChat_Permutation_n50_DFnet.txt
#
# 	 Detected: 98716 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21006
# ND: 25541
#
# Processing: CellChat_Permutation_n51_DFnet.txt
#
# 	 Detected: 100975 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26223
# ND: 25498
#
# Processing: CellChat_Permutation_n52_DFnet.txt
#
# 	 Detected: 101413 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 27012
# ND: 25673
#
# Processing: CellChat_Permutation_n53_DFnet.txt
#
# 	 Detected: 101679 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24780
# ND: 23941
#
# Processing: CellChat_Permutation_n54_DFnet.txt
#
# 	 Detected: 100150 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25738
# ND: 26891
#
# Processing: CellChat_Permutation_n55_DFnet.txt
#
# 	 Detected: 99520 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23633
# ND: 22541
#
# Processing: CellChat_Permutation_n56_DFnet.txt
#
# 	 Detected: 99871 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24099
# ND: 27936
#
# Processing: CellChat_Permutation_n57_DFnet.txt
#
# 	 Detected: 100675 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26318
# ND: 23482
#
# Processing: CellChat_Permutation_n58_DFnet.txt
#
# 	 Detected: 97855 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21436
# ND: 27379
#
# Processing: CellChat_Permutation_n59_DFnet.txt
#
# 	 Detected: 101343 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23522
# ND: 25600
#
# Processing: CellChat_Permutation_n6_DFnet.txt
#
# 	 Detected: 99051 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22717
# ND: 25618
#
# Processing: CellChat_Permutation_n60_DFnet.txt
#
# 	 Detected: 100267 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23569
# ND: 25062
#
# Processing: CellChat_Permutation_n61_DFnet.txt
#
# 	 Detected: 101286 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24340
# ND: 26430
#
# Processing: CellChat_Permutation_n62_DFnet.txt
#
# 	 Detected: 96315 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21016
# ND: 28467
#
# Processing: CellChat_Permutation_n63_DFnet.txt
#
# 	 Detected: 100624 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26255
# ND: 25017
#
# Processing: CellChat_Permutation_n64_DFnet.txt
#
# 	 Detected: 99191 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26166
# ND: 26930
#
# Processing: CellChat_Permutation_n65_DFnet.txt
#
# 	 Detected: 98729 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19772
# ND: 27104
#
# Processing: CellChat_Permutation_n66_DFnet.txt
#
# 	 Detected: 102149 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26131
# ND: 24828
#
# Processing: CellChat_Permutation_n67_DFnet.txt
#
# 	 Detected: 98906 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21741
# ND: 25475
#
# Processing: CellChat_Permutation_n68_DFnet.txt
#
# 	 Detected: 101909 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26472
# ND: 25797
#
# Processing: CellChat_Permutation_n69_DFnet.txt
#
# 	 Detected: 101547 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26741
# ND: 24423
#
# Processing: CellChat_Permutation_n7_DFnet.txt
#
# 	 Detected: 100376 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21880
# ND: 28613
#
# Processing: CellChat_Permutation_n70_DFnet.txt
#
# 	 Detected: 96512 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26285
# ND: 24618
#
# Processing: CellChat_Permutation_n71_DFnet.txt
#
# 	 Detected: 101467 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24615
# ND: 26125
#
# Processing: CellChat_Permutation_n72_DFnet.txt
#
# 	 Detected: 97608 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23588
# ND: 22174
#
# Processing: CellChat_Permutation_n73_DFnet.txt
#
# 	 Detected: 100827 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25067
# ND: 25592
#
# Processing: CellChat_Permutation_n74_DFnet.txt
#
# 	 Detected: 99517 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22190
# ND: 26015
#
# Processing: CellChat_Permutation_n75_DFnet.txt
#
# 	 Detected: 100971 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25325
# ND: 24778
#
# Processing: CellChat_Permutation_n76_DFnet.txt
#
# 	 Detected: 99108 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22414
# ND: 26175
#
# Processing: CellChat_Permutation_n77_DFnet.txt
#
# 	 Detected: 94929 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24861
# ND: 27014
#
# Processing: CellChat_Permutation_n78_DFnet.txt
#
# 	 Detected: 100961 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25573
# ND: 27366
#
# Processing: CellChat_Permutation_n79_DFnet.txt
#
# 	 Detected: 97093 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23888
# ND: 26896
#
# Processing: CellChat_Permutation_n8_DFnet.txt
#
# 	 Detected: 100816 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 23845
# ND: 25420
#
# Processing: CellChat_Permutation_n80_DFnet.txt
#
# 	 Detected: 99724 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24217
# ND: 24852
#
# Processing: CellChat_Permutation_n81_DFnet.txt
#
# 	 Detected: 97718 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21559
# ND: 29352
#
# Processing: CellChat_Permutation_n82_DFnet.txt
#
# 	 Detected: 98372 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26632
# ND: 26790
#
# Processing: CellChat_Permutation_n83_DFnet.txt
#
# 	 Detected: 97713 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19706
# ND: 26239
#
# Processing: CellChat_Permutation_n84_DFnet.txt
#
# 	 Detected: 99042 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24477
# ND: 26942
#
# Processing: CellChat_Permutation_n85_DFnet.txt
#
# 	 Detected: 97661 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21033
# ND: 27211
#
# Processing: CellChat_Permutation_n86_DFnet.txt
#
# 	 Detected: 99807 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25071
# ND: 25724
#
# Processing: CellChat_Permutation_n87_DFnet.txt
#
# 	 Detected: 96966 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 21886
# ND: 26195
#
# Processing: CellChat_Permutation_n88_DFnet.txt
#
# 	 Detected: 100825 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22103
# ND: 27382
#
# Processing: CellChat_Permutation_n89_DFnet.txt
#
# 	 Detected: 100253 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26923
# ND: 22683
#
# Processing: CellChat_Permutation_n9_DFnet.txt
#
# 	 Detected: 99613 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 27058
# ND: 26537
# Processing: CellChat_Permutation_n90_DFnet.txt
#
# 	 Detected: 99902 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22127
# ND: 24885
#
# Processing: CellChat_Permutation_n91_DFnet.txt
#
# 	 Detected: 101179 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 28949
# ND: 23285
#
# Processing: CellChat_Permutation_n92_DFnet.txt
#
# 	 Detected: 97206 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 27396
# ND: 20237
#
# Processing: CellChat_Permutation_n93_DFnet.txt
#
# 	 Detected: 96878 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 19895
# ND: 28296
#
# Processing: CellChat_Permutation_n94_DFnet.txt
#
# 	 Detected: 101228 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 26003
# ND: 24566
#
# Processing: CellChat_Permutation_n95_DFnet.txt
#
# 	 Detected: 99354 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22224
# ND: 24638
#
# Processing: CellChat_Permutation_n96_DFnet.txt
#
# 	 Detected: 100904 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25038
# ND: 24785
#
# Processing: CellChat_Permutation_n97_DFnet.txt
#
# 	 Detected: 100999 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 25895
# ND: 25650
#
# Processing: CellChat_Permutation_n98_DFnet.txt
#
# 	 Detected: 99113 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 22034
# ND: 27409
#
# Processing: CellChat_Permutation_n99_DFnet.txt
#
# 	 Detected: 100786 interactions
#
# Processing T1D_early vs ND
#
# Distribution of interactions in contrast:
# T1D_early: 24495
# ND: 28311
#
# Processing: CellChat_Permutation_n1_DFnet.txt
#
# 	 Detected: 99555 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23507
# ND: 22024
#
# Processing: CellChat_Permutation_n10_DFnet.txt
#
# 	 Detected: 100481 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23473
# ND: 27308
#
# Processing: CellChat_Permutation_n100_DFnet.txt
#
# 	 Detected: 100445 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26083
# ND: 26766
#
# Processing: CellChat_Permutation_n11_DFnet.txt
#
# 	 Detected: 100219 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23974
# ND: 27789
#
# Processing: CellChat_Permutation_n12_DFnet.txt
#
# 	 Detected: 99242 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23933
# ND: 23929
#
# Processing: CellChat_Permutation_n13_DFnet.txt
#
# 	 Detected: 101105 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23338
# ND: 26148
#
# Processing: CellChat_Permutation_n14_DFnet.txt
#
# 	 Detected: 100237 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24449
# ND: 25855
#
# Processing: CellChat_Permutation_n15_DFnet.txt
#
# 	 Detected: 100698 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 27298
# ND: 25895
#
# Processing: CellChat_Permutation_n16_DFnet.txt
#
# 	 Detected: 97143 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 27384
# ND: 25371
#
# Processing: CellChat_Permutation_n17_DFnet.txt
#
# 	 Detected: 98694 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23413
# ND: 23164
#
# Processing: CellChat_Permutation_n18_DFnet.txt
#
# 	 Detected: 101439 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24242
# ND: 26595
#
# Processing: CellChat_Permutation_n19_DFnet.txt
#
# 	 Detected: 95333 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25476
# ND: 27225
#
# Processing: CellChat_Permutation_n2_DFnet.txt
#
# 	 Detected: 99776 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24799
# ND: 26370
#
# Processing: CellChat_Permutation_n20_DFnet.txt
#
# 	 Detected: 99410 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25125
# ND: 25752
#
# Processing: CellChat_Permutation_n21_DFnet.txt
#
# 	 Detected: 98542 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24719
# ND: 26450
#
# Processing: CellChat_Permutation_n22_DFnet.txt
#
# 	 Detected: 101611 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24219
# ND: 25579
#
# Processing: CellChat_Permutation_n23_DFnet.txt
#
# 	 Detected: 99234 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25476
# ND: 24284
#
# Processing: CellChat_Permutation_n24_DFnet.txt
#
# 	 Detected: 97421 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24445
# ND: 27299
#
# Processing: CellChat_Permutation_n25_DFnet.txt
#
# 	 Detected: 98194 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25261
# ND: 27026
#
# Processing: CellChat_Permutation_n26_DFnet.txt
#
# 	 Detected: 100473 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23343
# ND: 27765
#
# Processing: CellChat_Permutation_n27_DFnet.txt
#
# 	 Detected: 98902 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24014
# ND: 26838
#
# Processing: CellChat_Permutation_n28_DFnet.txt
#
# 	 Detected: 101535 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25707
# ND: 24622
#
# Processing: CellChat_Permutation_n29_DFnet.txt
#
# 	 Detected: 101741 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25237
# ND: 22634
#
# Processing: CellChat_Permutation_n3_DFnet.txt
#
# 	 Detected: 100497 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 27411
# ND: 22418
#
# Processing: CellChat_Permutation_n30_DFnet.txt
#
# 	 Detected: 99336 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 28113
# ND: 25698
#
# Processing: CellChat_Permutation_n31_DFnet.txt
#
# 	 Detected: 99931 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25852
# ND: 25476
#
# Processing: CellChat_Permutation_n32_DFnet.txt
#
# 	 Detected: 101785 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24669
# ND: 24870
#
# Processing: CellChat_Permutation_n33_DFnet.txt
#
# 	 Detected: 95037 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25591
# ND: 28040
#
# Processing: CellChat_Permutation_n34_DFnet.txt
#
# 	 Detected: 95209 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24766
# ND: 26980
#
# Processing: CellChat_Permutation_n35_DFnet.txt
#
# 	 Detected: 100241 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26094
# ND: 24683
#
# Processing: CellChat_Permutation_n36_DFnet.txt
#
# 	 Detected: 99566 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26422
# ND: 26154
#
# Processing: CellChat_Permutation_n37_DFnet.txt
#
# 	 Detected: 100189 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23501
# ND: 26920
#
# Processing: CellChat_Permutation_n38_DFnet.txt
#
# 	 Detected: 101897 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24800
# ND: 24536
#
# Processing: CellChat_Permutation_n39_DFnet.txt
#
# 	 Detected: 100816 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24566
# ND: 25575
#
# Processing: CellChat_Permutation_n4_DFnet.txt
#
# 	 Detected: 98506 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24217
# ND: 25958
#
# Processing: CellChat_Permutation_n40_DFnet.txt
#
# 	 Detected: 101030 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25778
# ND: 25146
#
# Processing: CellChat_Permutation_n41_DFnet.txt
# 	 Detected: 100533 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24859
# ND: 26802
#
# Processing: CellChat_Permutation_n42_DFnet.txt
#
# 	 Detected: 101489 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23975
# ND: 27018
#
# Processing: CellChat_Permutation_n43_DFnet.txt
#
# 	 Detected: 99807 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23736
# ND: 22925
#
# Processing: CellChat_Permutation_n44_DFnet.txt
#
# 	 Detected: 97447 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26740
# ND: 27012
#
# Processing: CellChat_Permutation_n45_DFnet.txt
#
# 	 Detected: 100370 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 27607
# ND: 23792
#
# Processing: CellChat_Permutation_n46_DFnet.txt
#
# 	 Detected: 98702 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26255
# ND: 25907
#
# Processing: CellChat_Permutation_n47_DFnet.txt
#
# 	 Detected: 99726 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26384
# ND: 25710
#
# Processing: CellChat_Permutation_n48_DFnet.txt
#
# 	 Detected: 97819 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26694
# ND: 26628
#
# Processing: CellChat_Permutation_n49_DFnet.txt
#
# 	 Detected: 98560 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24939
# ND: 24813
#
# Processing: CellChat_Permutation_n5_DFnet.txt
#
# 	 Detected: 97817 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 28679
# ND: 25243
#
# Processing: CellChat_Permutation_n50_DFnet.txt
#
# 	 Detected: 98716 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26723
# ND: 25541
#
# Processing: CellChat_Permutation_n51_DFnet.txt
#
# 	 Detected: 100975 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24531
# ND: 25498
#
# Processing: CellChat_Permutation_n52_DFnet.txt
#
# 	 Detected: 101413 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26024
# ND: 25673
#
# Processing: CellChat_Permutation_n53_DFnet.txt
#
# 	 Detected: 101679 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24878
# ND: 23941
#
# Processing: CellChat_Permutation_n54_DFnet.txt
#
# 	 Detected: 100150 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23423
# ND: 26891
#
# Processing: CellChat_Permutation_n55_DFnet.txt
#
# 	 Detected: 99520 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 27416
# ND: 22541
#
# Processing: CellChat_Permutation_n56_DFnet.txt
#
# 	 Detected: 99871 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23997
# ND: 27936
#
# Processing: CellChat_Permutation_n57_DFnet.txt
#
# 	 Detected: 100675 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25479
# ND: 23482
#
# Processing: CellChat_Permutation_n58_DFnet.txt
#
# 	 Detected: 97855 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25566
# ND: 27379
#
# Processing: CellChat_Permutation_n59_DFnet.txt
#
# 	 Detected: 101343 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24707
# ND: 25600
#
# Processing: CellChat_Permutation_n6_DFnet.txt
#
# 	 Detected: 99051 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26336
# ND: 25618
#
# Processing: CellChat_Permutation_n60_DFnet.txt
#
# 	 Detected: 100267 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 28131
# ND: 25062
#
# Processing: CellChat_Permutation_n61_DFnet.txt
#
# 	 Detected: 101286 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23693
# ND: 26430
#
# Processing: CellChat_Permutation_n62_DFnet.txt
#
# 	 Detected: 96315 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 22414
# ND: 28467
#
# Processing: CellChat_Permutation_n63_DFnet.txt
#
# 	 Detected: 100624 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23617
# ND: 25017
#
# Processing: CellChat_Permutation_n64_DFnet.txt
#
# 	 Detected: 99191 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25053
# ND: 26930
#
# Processing: CellChat_Permutation_n65_DFnet.txt
#
# 	 Detected: 98729 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25909
# ND: 27104
#
# Processing: CellChat_Permutation_n66_DFnet.txt
#
# 	 Detected: 102149 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24676
# ND: 24828
#
# Processing: CellChat_Permutation_n67_DFnet.txt
#
# 	 Detected: 98906 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26738
# ND: 25475
#
# Processing: CellChat_Permutation_n68_DFnet.txt
#
# 	 Detected: 101909 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24714
# ND: 25797
#
# Processing: CellChat_Permutation_n69_DFnet.txt
#
# 	 Detected: 101547 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23628
# ND: 24423
#
# Processing: CellChat_Permutation_n7_DFnet.txt
#
# 	 Detected: 100376 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24640
# ND: 28613
#
# Processing: CellChat_Permutation_n70_DFnet.txt
#
# 	 Detected: 96512 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25968
# ND: 24618
#
# Processing: CellChat_Permutation_n71_DFnet.txt
#
# 	 Detected: 101467 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23595
# ND: 26125
#
# Processing: CellChat_Permutation_n72_DFnet.txt
#
# 	 Detected: 97608 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25927
# ND: 22174
#
# Processing: CellChat_Permutation_n73_DFnet.txt
#
# 	 Detected: 100827 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24475
# ND: 25592
#
# Processing: CellChat_Permutation_n74_DFnet.txt
#
# 	 Detected: 99517 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25742
# ND: 26015
#
# Processing: CellChat_Permutation_n75_DFnet.txt
#
# 	 Detected: 100971 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26648
# ND: 24778
#
# Processing: CellChat_Permutation_n76_DFnet.txt
#
# 	 Detected: 99108 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23430
# ND: 26175
#
# Processing: CellChat_Permutation_n77_DFnet.txt
#
# 	 Detected: 94929 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25092
# ND: 27014
#
# Processing: CellChat_Permutation_n78_DFnet.txt
#
# 	 Detected: 100961 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23554
# ND: 27366
#
# Processing: CellChat_Permutation_n79_DFnet.txt
#
# 	 Detected: 97093 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25828
# ND: 26896
#
# Processing: CellChat_Permutation_n8_DFnet.txt
#
# 	 Detected: 100816 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24842
# ND: 25420
#
# Processing: CellChat_Permutation_n80_DFnet.txt
#
# 	 Detected: 99724 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 27273
# ND: 24852
#
# Processing: CellChat_Permutation_n81_DFnet.txt
#
# 	 Detected: 97718 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23410
# ND: 29352
#
# Processing: CellChat_Permutation_n82_DFnet.txt
#
# 	 Detected: 98372 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23862
# ND: 26790
#
# Processing: CellChat_Permutation_n83_DFnet.txt
#
# 	 Detected: 97713 interactions
#
# Processing T1D_late vs ND
# Distribution of interactions in contrast:
# T1D_late: 26277
# ND: 26239
#
# Processing: CellChat_Permutation_n84_DFnet.txt
#
# 	 Detected: 99042 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25245
# ND: 26942
#
# Processing: CellChat_Permutation_n85_DFnet.txt
#
# 	 Detected: 97661 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24954
# ND: 27211
#
# Processing: CellChat_Permutation_n86_DFnet.txt
#
# 	 Detected: 99807 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26788
# ND: 25724
#
# Processing: CellChat_Permutation_n87_DFnet.txt
#
# 	 Detected: 96966 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25816
# ND: 26195
#
# Processing: CellChat_Permutation_n88_DFnet.txt
#
# 	 Detected: 100825 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24485
# ND: 27382
#
# Processing: CellChat_Permutation_n89_DFnet.txt
#
# 	 Detected: 100253 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24343
# ND: 22683
#
# Processing: CellChat_Permutation_n9_DFnet.txt
#
# 	 Detected: 99613 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 22471
# ND: 26537
#
# Processing: CellChat_Permutation_n90_DFnet.txt
#
# 	 Detected: 99902 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 26001
# ND: 24885
#
# Processing: CellChat_Permutation_n91_DFnet.txt
#
# 	 Detected: 101179 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24092
# ND: 23285
#
# Processing: CellChat_Permutation_n92_DFnet.txt
#
# 	 Detected: 97206 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24287
# ND: 20237
#
# Processing: CellChat_Permutation_n93_DFnet.txt
#
# 	 Detected: 96878 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23599
# ND: 28296
#
# Processing: CellChat_Permutation_n94_DFnet.txt
#
# 	 Detected: 101228 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23689
# ND: 24566
#
# Processing: CellChat_Permutation_n95_DFnet.txt
#
# 	 Detected: 99354 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 25906
# ND: 24638
#
# Processing: CellChat_Permutation_n96_DFnet.txt
#
# 	 Detected: 100904 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23961
# ND: 24785
#
# Processing: CellChat_Permutation_n97_DFnet.txt
#
# 	 Detected: 100999 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 22878
# ND: 25650
#
# Processing: CellChat_Permutation_n98_DFnet.txt
#
# 	 Detected: 99113 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 24739
# ND: 27409
#
# Processing: CellChat_Permutation_n99_DFnet.txt
#
# 	 Detected: 100786 interactions
#
# Processing T1D_late vs ND
#
# Distribution of interactions in contrast:
# T1D_late: 23667
# ND: 28311

# %%
stars = read.table(paste(permutations.test.res.dir, "Permutation.test_IS_Across_conditions.res", sep = ""),
                   header = TRUE, sep = "\t", row.names = 1, stringsAsFactors = FALSE)
stars.count= read.table(paste(permutations.test.res.dir, "Permutation.test_counts_Across_conditions.res", sep = ""),
                   header = TRUE, sep = "\t", row.names = 1, stringsAsFactors = FALSE)
stars.avg = read.table(paste(permutations.test.res.dir, "Permutation.test_avg_Across_conditions.res", sep = ""),
                   header = TRUE, sep = "\t", row.names = 1, stringsAsFactors = FALSE)

# %%
stars$condition = rownames(stars)
stars.count$condition = rownames(stars.count)
stars.avg$condition = rownames(stars.count)
colnames(stars) = c("IS.stars", "IS.pvalue", "condition")
colnames(stars.count) = c("Count.stars", "Count.pvalue", "condition")
colnames(stars.avg) = c("Avg.stars", "Avg.pvalue", "condition")

# %%
stars = merge(stars, stars.count, by = "condition")
stars = merge(stars, stars.avg, by = "condition")

# %%
# calculate FDR
stars$IS.pvalue[stars$IS.pvalue == 0] = 0.0001
stars$IS.FDR = p.adjust(stars$IS.pvalue, 'BH')
stars$Count.pvalue[stars$Count.pvalue == 0] = 0.0001
stars$Count.FDR = p.adjust(stars$Count.pvalue, 'BH')
stars$Avg.pvalue[stars$Avg.pvalue == 0] = 0.0001
stars$Avg.FDR = p.adjust(stars$Avg.pvalue, 'BH')
stars


# counting stars
stars$IS.stars = stars$IS.FDR
stars$IS.stars[stars$IS.FDR > 0.1]<-""
stars$IS.stars[stars$IS.FDR < 0.1]<-"*"
stars$IS.stars[stars$IS.FDR < 0.05]<-"**"
stars$IS.stars[stars$IS.FDR < 0.01]<-"***"

# counting stars
stars$IS.stars = stars$IS.FDR
stars$IS.stars[stars$IS.FDR > 0.1]<-""
stars$IS.stars[stars$IS.FDR < 0.1]<-"*"
stars$IS.stars[stars$IS.FDR < 0.05]<-"**"
stars$IS.stars[stars$IS.FDR < 0.01]<-"***"

# counting stars
stars$Count.stars = stars$Count.FDR
stars$Count.stars[stars$Count.FDR > 0.1]<-""
stars$Count.stars[stars$Count.FDR < 0.1]<-"*"
stars$Count.stars[stars$Count.FDR < 0.05]<-"**"
stars$Count.stars[stars$Count.FDR < 0.01]<-"***"

# counting stars
stars$Avg.stars = stars$Avg.FDR
stars$Avg.stars[stars$Avg.FDR > 0.1]<-""
stars$Avg.stars[stars$Avg.FDR < 0.1]<-"*"
stars$Avg.stars[stars$Avg.FDR < 0.05]<-"**"
stars$Avg.stars[stars$Avg.FDR < 0.01]<-"***"
# Out:
#   condition IS.stars IS.pvalue Count.stars Count.pvalue Avg.stars Avg.pvalue
# 1 Aab                0.96                  0.9500       NA        0.93
# 2 T1D_early          0.61      ***         0.0001       NA        0.19
# 3 T1D_late  *        0.03      ***         0.0001       NA        0.32
#   IS.FDR Count.FDR Avg.FDR
# 1 0.960  0.95000   0.93
# 2 0.915  0.00015   0.48
# 3 0.090  0.00015   0.48

# %% [markdown]
# # Plot

# %%
stat.data.plot = merge(stat.data, stars, by = "condition", all.x = TRUE)
# remove NAs
stat.data.plot[is.na(stat.data.plot)] = ""
stat.data.plot
# Out:
#   condition IS       Freq  average.IS  IS.stars IS.pvalue Count.stars
# 1 T1D_late  26.29345 14873 0.001767865 *        0.03      ***
# 2 T1D_early 36.27319 18179 0.001995335          0.61      ***
# 3 Aab       40.36969 27459 0.001470181          0.96
# 4 ND        40.59497 27139 0.001495817
#   Count.pvalue Avg.stars Avg.pvalue IS.FDR Count.FDR Avg.FDR
# 1 0.0001                 0.32       0.09   0.00015   0.48
# 2 0.0001                 0.19       0.915  0.00015   0.48
# 3 0.95                   0.93       0.96   0.95      0.93
# 4

# %%
position = position_dodge(width = 0.8)

gg1 = ggplot(stat.data.plot, aes(x = condition, y = IS, label = IS.stars)) +
    geom_bar(stat="identity", 
                     position = position, width = 0.7,
                     colour="black") +
            scale_fill_manual(values= colors.conditions)+
    labs(y= "Interaction - strength", x = "") +
    ylim(0, 50)+
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()+
    geom_text(hjust = -1, size = 3)

gg2 = ggplot(stat.data.plot, aes(x = condition, y = Freq, label = Count.stars)) +
    geom_bar(stat="identity", 
                     position = position, width = 0.7,
                     colour="black") +
            scale_fill_manual(values= colors.conditions)+
    labs(y= "Number of interactions", x = "") +
    ylim(0, 30000)+
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()+
    geom_text(hjust = -1, size = 3)

gg3 = ggplot(stat.data.plot, aes(x = condition, y = average.IS, label = Avg.FDR)) +
    geom_bar(stat="identity", 
                     position = position, width = 0.7,
                     colour="black") +
            scale_fill_manual(values= colors.conditions)+
    labs(y= "Average Interaction - strength", x = "") +
    ylim(0, 0.003)+
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()+
    geom_text(hjust = -1, size = 3)

# %%
options(repr.plot.width=15, repr.plot.height=5)
grid.arrange(gg1, gg2, gg3, ncol = 3)
# Out:
# plot without title

# %%
file = paste(permutations.test.res.dir, "Overall_IS.pdf", sep = "")
ggsave(file, gg1,
       width = 5, height = 5, 
       device = "pdf")

file = paste(permutations.test.res.dir, "Overall_InteractionCount.pdf", sep = "")
ggsave(file, gg2,
       width = 5, height = 5, 
       device = "pdf")

file = paste(permutations.test.res.dir, "Average_IS.pdf", sep = "")
ggsave(file, gg3,
       width = 5, height = 5, 
       device = "pdf")

# %%
permutations.test.res.dir
# Out:
# [1] "/nfs/lab/projects/CellCrosstalk/npod.pancreas/Final/Results/corrected.permutation.test/Results/"

# %%
file.name = paste(permutations.test.res.dir, "Permutation.test_overall_changes.res", sep = "")
write.table(stat.data.plot, file.name, sep = "\t", quote = F, col.names=T, row.names = T)

# %%
# Plot by celltype and use overall permutation test for stars

# %%
LR.data.consensus.sig.thresh = read.table(paste(results.dir,
                                               "LR.data.consensus.sig.thresh.txt", sep = ""),
                                          sep = "\t", stringsAsFactors = F, header = T)
LR.data.consensus.sig.thresh = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$target %in% cell.pop.order, ]
LR.data.consensus.sig.thresh = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$source %in% cell.pop.order, ]

# %%
order.comp = rev(c("Endocrine", "Immune", "Endothelial", "Stromal", "Exocrine"))

# %%
# IS
data.source <- aggregate(prob ~ compartment.source + condition, LR.data.consensus.sig.thresh, sum)
data.target <- aggregate(prob ~ compartment.target + condition, LR.data.consensus.sig.thresh, sum)
colnames(data.source)[1] = "compartment"
colnames(data.target)[1] = "compartment"
data = rbind(data.source, data.target)
data.plot <- aggregate(prob ~ compartment + condition, data, sum)

# prep to plot
data.plot = data.plot %>%
  dplyr::mutate(prob.norm = prob / condition.sizes[as.character(condition)]) %>%
  dplyr::mutate(compartment = factor(compartment, levels = order.comp)) %>%
  dplyr::mutate(condition = factor(condition, levels = rev(condition.ls))) %>%
  dplyr::arrange(compartment)

# %%
options(repr.plot.width=7, repr.plot.height=5)
gg3 = ggplot(data.plot, aes(x = condition, y = prob, fill = compartment)) +
    geom_bar(stat="identity", width = 0.6, colour="black", linewidth = 0.6) +
    scale_fill_manual(values= colors.compartments)+
    labs(y= "Interaction - strength", x = "") +
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()

# %%
# prep to plot
data.source = data.source %>%
  dplyr::mutate(prob.norm = prob / condition.sizes[as.character(condition)]) %>%
  dplyr::mutate(compartment = factor(compartment, levels = order.comp)) %>%
  dplyr::mutate(condition = factor(condition, levels = rev(condition.ls))) %>%
  dplyr::arrange(compartment)

# %%
options(repr.plot.width=7, repr.plot.height=5)
gg1 = ggplot(data.source, aes(x = condition, y = prob, fill = compartment)) +
    geom_bar(stat="identity", width = 0.6, colour="black", linewidth = 0.6) +
    scale_fill_manual(values= colors.compartments)+
    labs(y= "Interaction - strength", x = "") +
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()

# %%
# prep to plot
data.target = data.target %>%
  dplyr::mutate(prob.norm = prob / condition.sizes[as.character(condition)]) %>%
  dplyr::mutate(compartment = factor(compartment, 
                            levels = order.comp)) %>%
  dplyr::mutate(condition = factor(condition, levels = rev(condition.ls))) %>%
  dplyr::arrange(compartment)

# %%
options(repr.plot.width=7, repr.plot.height=5)
gg2 = ggplot(data.target, aes(x = condition, y = prob, fill = compartment)) +
    geom_bar(stat="identity", width = 0.6, colour="black", linewidth = 0.6) +
    scale_fill_manual(values= colors.compartments)+
    labs(y= "Interaction - strength", x = "") +
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()

# %%
options(repr.plot.width=20, repr.plot.height=5)
grid.arrange(gg1, gg2, gg3, ncol = 3)
# Out:
# plot without title

# %%
file = paste(permutations.test.res.dir, "IS_Outgoing_Bycategory.pdf", sep = "")
ggsave(file, gg1,
       width = 5, height = 5, 
       device = "pdf")

file = paste(permutations.test.res.dir, "IS_Incoming_Bycategory.pdf", sep = "")
ggsave(file, gg2,
       width = 5, height = 5, 
       device = "pdf")

file = paste(permutations.test.res.dir, "IS_Out+in.pdf", sep = "")
ggsave(file, gg3,
       width = 5, height = 5, 
       device = "pdf")

# %%
# count
data.source <- LR.data.consensus.sig.thresh %>%
    dplyr::mutate(condition.compartment = paste0(condition, "--", compartment.source)) %>%
    dplyr::group_by(condition.compartment) %>%
    dplyr::summarize(count = n())%>%
    dplyr::mutate(condition = str_split_fixed(condition.compartment, "--", 2)[,1],
                  compartment = str_split_fixed(condition.compartment, "--", 2)[,2],)%>%
    dplyr::select(-condition.compartment)%>%
    dplyr::ungroup() %>%
    dplyr::mutate(compartment = factor(compartment, 
                            levels = order.comp)) %>%
    dplyr::mutate(condition = factor(condition, levels = rev(condition.ls))) %>%
    dplyr::arrange(compartment)

data.target <- LR.data.consensus.sig.thresh %>%
    dplyr::mutate(condition.compartment = paste0(condition, "--", compartment.target)) %>%
    dplyr::group_by(condition.compartment) %>%
    dplyr::summarize(count = n())%>%
    dplyr::mutate(condition = str_split_fixed(condition.compartment, "--", 2)[,1],
                  compartment = str_split_fixed(condition.compartment, "--", 2)[,2],)%>%
    dplyr::select(-condition.compartment)%>%
    dplyr::ungroup()%>%
    dplyr::mutate(compartment = factor(compartment, 
                            levels = order.comp)) %>%
    dplyr::mutate(condition = factor(condition, levels = rev(condition.ls))) %>%
    dplyr::arrange(compartment)

# %%
options(repr.plot.width=7, repr.plot.height=5)
gg1 = ggplot(data.source, aes(x = condition, y = count, fill = compartment)) +
    geom_bar(stat="identity", width = 0.6, colour="black", linewidth = 0.6) +
    scale_fill_manual(values= colors.compartments)+
    labs(y= "Number of interactions", x = "") +
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()

# %%
options(repr.plot.width=7, repr.plot.height=5)
gg2 = ggplot(data.target, aes(x = condition, y = count, fill = compartment)) +
    geom_bar(stat="identity", width = 0.6, colour="black", linewidth = 0.6) +
    scale_fill_manual(values= colors.compartments)+
    labs(y= "Number of interactions", x = "") +
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()

# %%
data = rbind(data.source, data.target)
data.plot <- aggregate(count ~ compartment + condition, data, sum)

# %%
options(repr.plot.width=7, repr.plot.height=5)
gg3 = ggplot(data.plot, aes(x = condition, y = count, fill = compartment)) +
    geom_bar(stat="identity", width = 0.6, colour="black", linewidth = 0.6) +
    scale_fill_manual(values= colors.compartments)+
    labs(y= "Number of interactions", x = "") +
    theme_bw() +
    theme(axis.text = element_text(size = 12), axis.title = element_text(size = 12, face = "bold"), 
                         plot.title = element_text(size = 18, face = "bold", , hjust = 0.5))+
    coord_flip()

# %%
options(repr.plot.width=20, repr.plot.height=5)
grid.arrange(gg1, gg2, gg3, ncol = 3)
# Out:
# plot without title

# %%
file = paste(permutations.test.res.dir, "Interaction_Number_Outgoing_Bycategory.pdf", sep = "")
ggsave(file, gg1,
       width = 5, height = 5, 
       device = "pdf")

file = paste(permutations.test.res.dir, "Interaction_Number_Incoming_Bycategory.pdf", sep = "")
ggsave(file, gg2,
       width = 5, height = 5, 
       device = "pdf")

file = paste(permutations.test.res.dir, "Interaction_Number_Out+in.pdf", sep = "")
ggsave(file, gg3,
       width = 5, height = 5, 
       device = "pdf")

# %%
permutations.test.res.dir
# Out:
# [1] "/nfs/lab/projects/CellCrosstalk/npod.pancreas/Final/Results/corrected.permutation.test/Results/"
