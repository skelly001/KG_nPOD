# %%
options(scipen=999)
options(width = 10000)
pacman::p_load(dplyr, stringr, data.table, tidyr, plyr, forcats, logr,grid, ggh4x,
               Rmagic, phateR, parallel,gridExtra,ggplot2, ggpubr, ggrepel, ggbreak, gridExtra, patchwork, grid, ggh4x,
               pheatmap, colorRamps, gridExtra, ggplot2, ggrepel, RColorBrewer,ComplexHeatmap,vioplot,ggforce,grid)

# %%
# Set working directories
base.dir =  "/nfs/lab/projects/CellCrosstalk/npod.pancreas/Final/"
assets.dir = paste(base.dir, "Assets/", sep = "") 
results.dir = paste(base.dir, "Results/corrected/", sep = "")
permutation.result.dir = paste(base.dir, "Results/corrected.permutation.test/", sep = "")


# Databases
cc.db = "/nfs/lab/projects/islet_multiomics_stress/analysis/CellChat/Assets/CellChatDB.human.txt"
Gaulton.db.dir = "/nfs/lab/Luca/Assets/LR.Database/GaultonDB_V2.txt"

permutations.test.tmp.dir = paste(permutation.result.dir, "TMP/", sep = "")
permutations.test.res.dir = paste(permutation.result.dir, "Results/", sep = "")

cc.db = "/nfs/lab/projects/islet_multiomics_stress/analysis/CellChat/Assets/CellChatDB.human.txt"

# %%
# Permutation test results:
diff.analysis.dir.ls = c(paste(permutations.test.res.dir, 
                                  "Permutation.test_Aab.Vs.ND_LR.level.interactions.all.columns.res", 
                                 sep = ""), 
                            paste(permutations.test.res.dir, 
                                  "Permutation.test_T1D_early.Vs.ND_LR.level.interactions.all.columns.res",
                                 sep = ""),
                            paste(permutations.test.res.dir, 
                                  "Permutation.test_T1D_late.Vs.ND_LR.level.interactions.all.columns.res",
                                 sep = ""))

# %% [markdown]
# # Load SM DBs

# %%
# Load and prepare Gaulton DB
Gaulton.db.dir = "/nfs/lab/Luca/Assets/LR.Database/GaultonDB_V2.txt"
# Load list of ligands and receptors
SM.ls.df = read.table(paste(assets.dir, "SM.ls.df.txt", sep=""), sep = "\t", stringsAsFactors = F, header = T)
SM.ls = unique(SM.ls.df$gene)
length(SM.ls)

# Load database
cc.db.data = read.table(cc.db, sep = "\t", stringsAsFactors = F, header = T)
# cc.db.data = cc.db.data[,c(11,2,3)]
message("CCDB number of interactions: ", length(levels(factor(cc.db.data$interaction_name))))

gaulton.db.data = read.table(Gaulton.db.dir, sep = "\t", stringsAsFactors = F, header = T)
colnames(gaulton.db.data)[1] = "gene"

SM.ls.df.GDB = merge(SM.ls.df, gaulton.db.data, by = "gene", all.x = TRUE)
SM.ls.df.GDB[is.na(SM.ls.df.GDB)] <- ""

# Calculate category sizes
categories.size = SM.ls.df.GDB[SM.ls.df.GDB$Type == "Ligand",]

# Ligands
ligands.GDB = filter(SM.ls.df.GDB, Type != "Receptor")
colnames(ligands.GDB)[1] = "ligand"
head(ligands.GDB)

# Make a list of all ligands
ligands.ls = c(unique(cc.db.data$ligand), 
              str_split_fixed(unique(cc.db.data$ligand[grepl("_", cc.db.data$ligand)]), "_", n = 2)[,1],
              str_split_fixed(unique(cc.db.data$ligand[grepl("_", cc.db.data$ligand)]), "_", n = 2)[,2])
ligands.ls = unique(ligands.ls)
ligands.ls = ligands.ls[ligands.ls %in% SM.ls]
# Make a list of all receptors
receptors.ls = c(unique(cc.db.data$receptor),
                 str_split_fixed(unique(cc.db.data$receptor[grepl("_", cc.db.data$receptor)]), "_", n = 2)[,1],
                 str_split_fixed(unique(cc.db.data$receptor[grepl("_", cc.db.data$receptor)]), "_", n = 2)[,2])
receptors.ls = unique(receptors.ls)
receptors.ls = receptors.ls[receptors.ls %in% SM.ls]

# Make a list of all receptors that are also ligands
both = ligands.ls[ligands.ls %in% receptors.ls]
message("Number of ligands that are also receptors: ", length(both))


# Exclude those from the other lists
receptors.ls = receptors.ls[!receptors.ls %in% both]
message("Number of receptors: ", length(receptors.ls))


# Exclude those from the other lists
ligands.ls = ligands.ls[!ligands.ls %in% both]
message("Number of ligands: ", length(ligands.ls))


#Check that the length is 860
message("Final Number of SM: ", length(ligands.ls) + length(receptors.ls) + length(both))

Interaction.type.ls = c("Secreted Signaling", "Cell-Cell Contact", "ECM-Receptor")

Functional.classification.order = c('Hormones & Neuropeptides', 'Enzymes', 'Developmental Proteins', 
                                    'Growth Factors and Cytokines', 'Antigen-Presenting Molecules', 'Complement System',
                                    'Immune regulators', 'Modulators', 'Cell Adhesion Molecule', 'ECM Proteins')
# Out:
# [1] 857
# CCDB number of interactions: 1939
#   ligand  Type   Mode.of.Action     Functional.classification    Functional.sub.classification Gene.Family
# 1 ADCYAP1 Ligand Secreted Signaling Modulators                   Adenylyl Cyclase Modulator    PACAP Family
# 2 ADGRE5  Ligand Cell-Cell Contact  Cell Adhesion Molecule       Other Cell Adhesion Proteins  -
# 3 ADIPOQ  Ligand Secreted Signaling Growth Factors and Cytokines Other Cytokines               Adipokine Family
# 4 ADM     Ligand Secreted Signaling Hormones & Neuropeptides     Hormone (Heart)               Adrenomedullin Family
# 5 AGRN    Ligand ECM-Receptor       ECM Proteins                 Other ECM proteins            Agrin Family
# 6 AGT     Ligand Secreted Signaling Hormones & Neuropeptides     Hormone (Liver)               Angiotensinogen Family
# Number of ligands that are also receptors: 54
#
# Number of receptors: 379
#
# Number of ligands: 424
#
# Final Number of SM: 857

# %%
Functional.classification.order = c('Hormones & Neuropeptides', 'Enzymes', 'Developmental Proteins', 
                                    'Growth Factors and Cytokines', 'Antigen-Presenting Molecules', 'Complement System', 'Immune regulators',
                                    'Modulators', 'Cell Adhesion Molecule', 'ECM Proteins')

# %% [markdown]
# # Define cellular compartments

# %%
# conditions
condition.ls = c("ND", "Aab", "T1D_early","T1D_late")

colors.conditions = c("ND" = "#85EF1B",
                      "Aab" = "#EFEF1B",
                      "T1D_early" = "#EF851B",
                      "T1D_late" = "#EF1B1B")

# Contrasts
Contrast_1 = c(condition.ls[2], condition.ls[3], condition.ls[4])
Contrast_2 = c(condition.ls[1], condition.ls[1], condition.ls[1])

# Celltypes and compartments
Endocrine = c('Alpha', 'Beta', 'Delta')
Exocrine = c('Acinar1_2_6','Acinar_3','Acinar_4','Acinar_5','Ductal','MUC5b_Ductal')
Immune = c('Tcells','Macrophage')
Endothelial = c('Endothelial')
Stromal = c('Activated_Stellate','Quiescent_Stellate')

cell.pop.order = c(Endocrine, Exocrine, Immune, Endothelial, Stromal)
rev.cell.pop.order = c(rev(Stromal), rev(Endothelial), rev(Immune), rev(Exocrine), rev(Endocrine), use.names = TRUE)

compartment = cell.pop.order
compartment = ifelse(compartment  %in%  Endocrine, "Endocrine", 
                 ifelse(compartment  %in%  Exocrine, "Exocrine",
                        ifelse(compartment  %in%  Immune, "Immune",
                               ifelse(compartment  %in%  Endothelial, "Endothelial", "Stromal"))))

Cellpop.compartment = as.data.frame(cbind(cell.pop.order, compartment))
Cellpop.compartment$compartment = factor(Cellpop.compartment$compartment, levels = c('Endocrine','Exocrine','Immune','Endothelial', "Stromal"))
colnames(Cellpop.compartment)[1] = "Celltype"

colors.compartments = c('Endocrine'='#26bfbf',
           'Exocrine'='#ed872d',
           'Immune'='#3F98E0',
           'Endothelial'='#800080',
           'Stromal'='#F5DE6C')

Cellpop.compartment$colors.compartments = compartment
Cellpop.compartment$colors.compartments = mapvalues(Cellpop.compartment$colors.compartments, names(colors.compartments), colors.compartments, warn_missing = TRUE)
gaps.compartments = c(3, 9, 11, 12)

# %% [markdown]
# # Permutation test

# %%
LR.data.consensus.sig.thresh = read.table(paste(results.dir,
                                               "LR.data.consensus.sig.thresh.txt", sep = ""),
                                          sep = "\t", stringsAsFactors = F, header = T)
LR.data.consensus.sig.thresh = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$target %in% cell.pop.order, ]
LR.data.consensus.sig.thresh = LR.data.consensus.sig.thresh[LR.data.consensus.sig.thresh$source %in% cell.pop.order, ]

# %%
filter(LR.data.consensus.sig.thresh, interaction.id == "Acinar_3--Activated_Stellate--PRSS1--F2RL2") %>% 
      select(interaction.id, condition, prob)
# Out:
#       interaction.id                             condition prob
# 64382 Acinar_3--Activated_Stellate--PRSS1--F2RL2 Aab       0.000166088

# %%
# Split data to save FDR and prob 
obs.data.stats.ls = list()

## Create ID column
LR.data.stats = LR.data.consensus.sig.thresh
# Keep only interaction ID, condition, FDR and Prob
LR.data.stats = LR.data.stats[,c(14, 12, 13, 5)]


message("Splitting conditions")
for (i in seq_along(condition.ls)){
    gc(reset = TRUE)
    condition.use = condition.ls[i]
    print(condition.use)
    obs.data.stats.ls[[i]] = LR.data.stats[LR.data.stats$condition == condition.use, ]
}
# Out:
# Splitting conditions
# [1] "ND"
# [1] "Aab"
# [1] "T1D_early"
# [1] "T1D_late"

# %% [markdown]
# ## Observed value

# %%
diff.obs = vector(mode = "list", length = length(Contrast_1))
abs.diff.obs = vector(mode = "list", length = length(Contrast_1))
interaction.id.ls = vector(mode = "list", length = length(Contrast_1))

for (i in seq_along(Contrast_1)){
    LR.data.use <- LR.data.consensus.sig.thresh
    message("Detected: ", nrow(LR.data.use), " significant interactions ")
    # Subset for the contrast
    message("Processing ", Contrast_1[i], " vs ", Contrast_2[i])
    contrast = c(Contrast_1[i], Contrast_2[i])
    # make a table of Interaction ID for the contrast (to gather all interactions)
    LR.data.use = LR.data.use[LR.data.use$condition %in% contrast, ]
    message("\t - Detected: ", nrow(LR.data.use), " overall significant interactions in 2 contrasts")
    # Split the dataset
    LR.data.c1 = LR.data.use[LR.data.use$condition %in% contrast[1], ]
    LR.data.c2 = LR.data.use[LR.data.use$condition %in% contrast[2], ]
    message("\t - Distribution of interactions: \n\t   - ",
            Contrast_1[i], ": ", nrow(LR.data.c1), "\n\t   - ",
            Contrast_2[i], ": ", nrow(LR.data.c2))
    # Merge the dataset to have a list of common and unique interactions
    interaction.id.ls[[i]] = merge(LR.data.c1, LR.data.c2, by = "interaction.id", all = TRUE)
    interaction.id.ls[[i]] = as.data.frame(interaction.id.ls[[i]]$interaction.id)
    colnames(interaction.id.ls[[i]]) = "interaction.id"
    message("\t - Detected: ", nrow(interaction.id.ls[[i]]), " unique interactions")
    # Complete data frame to always have all data
    LR.data.c1 = merge(LR.data.c1, interaction.id.ls[[i]], by = "interaction.id", all.y = TRUE)
    LR.data.c2 = merge(LR.data.c2, interaction.id.ls[[i]], by = "interaction.id", all.y = TRUE)
    message("\t - Check that contrasts have same number of interactions: \n\t   - ",
            Contrast_1[i], ": ", nrow(LR.data.c1), "\n\t   - ",
            Contrast_2[i], ": ", nrow(LR.data.c2))
    # Replace NA with 0
    LR.data.c1$prob[is.na(LR.data.c1$prob)] = 0
    LR.data.c2$prob[is.na(LR.data.c2$prob)] = 0
    ## Change rownames
    rownames(LR.data.c1) = LR.data.c1$interaction.id
    rownames(LR.data.c2) = LR.data.c2$interaction.id
    ## Re-order
    LR.data.c1 <- LR.data.c1[order(match(rownames(LR.data.c1), interaction.id.ls[[i]]$interaction.id)), , drop = FALSE]
    LR.data.c2 <- LR.data.c2[order(match(rownames(LR.data.c2), interaction.id.ls[[i]]$interaction.id)), , drop = FALSE]  
    # Compute normalized difference and effect size
    diff.obs[[i]] = LR.data.c1$prob - LR.data.c2$prob
    names(diff.obs[[i]]) = interaction.id.ls[[i]]$interaction.id
    abs.diff.obs[[i]] = abs(diff.obs[[i]])
}
# Out:
# Detected: 87650 significant interactions
#
# Processing Aab vs ND
#
# 	 - Detected: 54598 overall significant interactions in 2 contrasts
#
# 	 - Distribution of interactions:
# 	   - Aab: 27459
# 	   - ND: 27139
#
# 	 - Detected: 31481 unique interactions
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
# Detected: 87650 significant interactions
#
# Processing T1D_early vs ND
#
# 	 - Detected: 45318 overall significant interactions in 2 contrasts
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 18179
# 	   - ND: 27139
#
# 	 - Detected: 29393 unique interactions
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
# Detected: 87650 significant interactions
#
# Processing T1D_late vs ND
#
# 	 - Detected: 42012 overall significant interactions in 2 contrasts
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 14873
# 	   - ND: 27139
#
# 	 - Detected: 28644 unique interactions
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644

# %% [markdown]
# ## Compare with simulation

# %%
nsim = 100

# %%
for (i in seq_along(Contrast_1)){
    setwd(permutations.test.tmp.dir)
    print(paste("Processing ", Contrast_1[i], " vs ", Contrast_2[i], sep =""))
    # Get files
    sim.list <- dir(pattern = "_DFnet.txt")
    diff.sim.data = NULL
    abs.diff.sim.data = NULL
    for (s.i in seq_along(sim.list)){
        message(" - Processing: ", sim.list[s.i])
        # Load simulation data
        LR.data.use <- read.table(sim.list[s.i], sep = "\t", stringsAsFactors = F, header = T)
        # Replace interaction ID with new one
        LR.data.use = LR.data.use[,-1]
        # Subset for the contrast
        contrast = c(Contrast_1[i], Contrast_2[i])
        # make a table of Interaction ID for the contrast (to gather all interactions)
        LR.data.use = LR.data.use[LR.data.use$condition %in% contrast, ]
        message("\t - Detected: ", nrow(LR.data.use), " significant interactions in contrast")
        LR.data.c1 = LR.data.use[LR.data.use$condition %in% contrast[1], ]
        LR.data.c2 = LR.data.use[LR.data.use$condition %in% contrast[2], ]
        message("\t - Distribution of interactions: \n\t   - ",
                Contrast_1[i], ": ", nrow(LR.data.c1), "\n\t   - ",
                Contrast_2[i], ": ", nrow(LR.data.c2))
        message("\t - Detected: ", nrow(interaction.id.ls[[i]]), " unique interactions from the observations")
        # Complete data frame to always have all data
        LR.data.c1 = merge(LR.data.c1, interaction.id.ls[[i]], by = "interaction.id", all.y = TRUE)
        LR.data.c2 = merge(LR.data.c2, interaction.id.ls[[i]], by = "interaction.id", all.y = TRUE)
        message("\t - Check that contrasts have same number of interactions: \n\t   - ",
            Contrast_1[i], ": ", nrow(LR.data.c1), "\n\t   - ",
            Contrast_2[i], ": ", nrow(LR.data.c2))
        # Replace NA with 0
        LR.data.c1$prob[is.na(LR.data.c1$prob)] = 0
        LR.data.c2$prob[is.na(LR.data.c2$prob)] = 0
        ## Change rownames
        rownames(LR.data.c1) = LR.data.c1$interaction.id
        rownames(LR.data.c2) = LR.data.c2$interaction.id
        ## Re-order
        LR.data.c1 <- LR.data.c1[order(match(rownames(LR.data.c1), interaction.id.ls[[i]]$interaction.id)), , drop = FALSE]
        LR.data.c2 <- LR.data.c2[order(match(rownames(LR.data.c2), interaction.id.ls[[i]]$interaction.id)), , drop = FALSE]
        # Compute difference
        diff.sim = LR.data.c1$prob - LR.data.c2$prob
        names(diff.sim) = interaction.id.ls[[i]]$interaction.id
        abs.diff.sim = abs(diff.sim)
        # pile up results
        diff.sim.data = cbind(diff.sim.data, diff.sim)
        colnames(diff.sim.data)[ncol(diff.sim.data)] = s.i
        abs.diff.sim.data = cbind(abs.diff.sim.data, abs.diff.sim)
        colnames(abs.diff.sim.data)[ncol(abs.diff.sim.data)] = s.i
    }
    message("Comparing simulations against observations")
    random.success.table = abs.diff.sim.data > abs.diff.obs[[i]]
    random.success = rowSums(random.success.table == "TRUE", na.rm = TRUE)
    pvalue = random.success/nsim
    pvalue = replace(pvalue, diff.obs[[i]] == 0, 1)    
    check = diff.obs[[i]] == 0
    check = length(check[check==TRUE])
    message("\t - # Of null observed differential interactions (should be 0 for this analysis): ", check)
    # Make dataframe for stars
    stars = pvalue
    stars[pvalue<=0.05]<-"*"
    stars[pvalue<=0.01]<-"**"
    stars[pvalue==0]<-"***"
    stars[pvalue>0.05]<-""
    diff.analysis = data.frame(contrast.pvalue = pvalue)
    diff.analysis$stars = stars
    diff.analysis$contrasts = paste(Contrast_1[i], ".Vs.", Contrast_2[i], sep = "")
    diff.analysis$interaction.id = rownames(diff.analysis)
    diff.analysis$source = str_split_fixed(diff.analysis$interaction.id, "--", 4)[,1]
    diff.analysis$target = str_split_fixed(diff.analysis$interaction.id, "--", 4)[,2]
    diff.analysis$ligand = str_split_fixed(diff.analysis$interaction.id, "--", 4)[,3]
    diff.analysis$receptor = str_split_fixed(diff.analysis$interaction.id, "--", 4)[,4]
        # Load observation references (First dataset of the list is ND, so I have to add the +1)
        contrast.stats.1 = as.data.frame(obs.data.stats.ls[i + 1])
        ## Second contarst is always ND
        contrast.stats.2 = as.data.frame(obs.data.stats.ls[[1]])
        message("\t - Grabbing observed prob and pvalue: \n\t   - ",
                Contrast_1[i], ": ", nrow(contrast.stats.1), "\n\t   - ",
                Contrast_2[i], ": ", nrow(contrast.stats.2))
        # Subset to just interactions in contrast
        contrast.stats.1 = merge(contrast.stats.1, interaction.id.ls[[i]], by = "interaction.id", all.y = TRUE)
        contrast.stats.2 = merge(contrast.stats.2, interaction.id.ls[[i]], by = "interaction.id", all.y = TRUE)
        # Replace NA with condition name
        contrast.stats.1$condition[is.na(contrast.stats.1$condition)] = Contrast_1[i]
        contrast.stats.2$condition[is.na(contrast.stats.2$condition)] = Contrast_2[i]
        ## Change rownames
        message("\t - Post subset for contrast interactions: \n\t   - ",
                Contrast_1[i], ": ", nrow(contrast.stats.1), "\n\t   - ",
                Contrast_2[i], ": ", nrow(contrast.stats.2))
        rownames(contrast.stats.1) = contrast.stats.1$interaction.id
        rownames(contrast.stats.2) = contrast.stats.2$interaction.id
        ## Re-order
        contrast.stats.1 <- contrast.stats.1[order(match(rownames(contrast.stats.1), interaction.id.ls[[i]]$interaction.id)), , drop = FALSE]
        contrast.stats.2 <- contrast.stats.2[order(match(rownames(contrast.stats.2), interaction.id.ls[[i]]$interaction.id)), , drop = FALSE]
        # bind observed statistics
        diff.analysis$obs.contrast1.prob = contrast.stats.1$prob
        diff.analysis$obs.contrast1.FDR = contrast.stats.1$FDR
        diff.analysis$obs.contrast1.condition = contrast.stats.1$condition
        diff.analysis$obs.contrast2.prob = contrast.stats.2$prob
        diff.analysis$obs.contrast2.FDR = contrast.stats.2$FDR
        diff.analysis$obs.contrast2.condition = contrast.stats.2$condition
        diff.analysis$diff.obs = diff.obs[[i]]    
        # Order collumns
        diff.analysis = diff.analysis[,c(4,5,6,7,8,
                                         11,14,3,
                                         10,13,
                                         9,12,15,
                                         1,2)]
    setwd(permutations.test.res.dir)
    file.name = paste("Permutation.test_", Contrast_1[i], ".Vs.", Contrast_2[i], "_LR.level.interactions.all.columns.res", sep = "")
    write.table(diff.analysis, file.name, sep = "\t", quote = F, col.names=T, row.names = F)    
    
    
    
    diff.analysis = diff.analysis[,c(1, 6, 15)]
    colnames(diff.analysis) = c("interaction.id", "condition", "stars")
    file.name = paste("Permutation.test_", Contrast_1[i], ".Vs.", Contrast_2[i], "_LR.level.interactions.res", sep = "")
    write.table(diff.analysis, file.name, sep = "\t", quote = F, col.names=T, row.names = F)  
}
# Out:
# [1] "Processing Aab vs ND"
#  - Processing: CellChat_Permutation_n1_DFnet.txt
#
# 	 - Detected: 49488 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27464
# 	   - ND: 22024
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n10_DFnet.txt
#
# 	 - Detected: 53239 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25931
# 	   - ND: 27308
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n100_DFnet.txt
#
# 	 - Detected: 50674 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23908
# 	   - ND: 26766
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n11_DFnet.txt
#
# 	 - Detected: 53665 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25876
# 	   - ND: 27789
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n12_DFnet.txt
#
# 	 - Detected: 50948 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27019
# 	   - ND: 23929
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n13_DFnet.txt
#
# 	 - Detected: 52151 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26003
# 	   - ND: 26148
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n14_DFnet.txt
#
# 	 - Detected: 52324 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26469
# 	   - ND: 25855
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n15_DFnet.txt
#
# 	 - Detected: 51013 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25118
# 	   - ND: 25895
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n16_DFnet.txt
#
# 	 - Detected: 50387 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25016
# 	   - ND: 25371
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n17_DFnet.txt
#
# 	 - Detected: 50282 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27118
# 	   - ND: 23164
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n18_DFnet.txt
#
# 	 - Detected: 50118 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23523
# 	   - ND: 26595
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n19_DFnet.txt
#
# 	 - Detected: 50308 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23083
# 	   - ND: 27225
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n2_DFnet.txt
#
# 	 - Detected: 54381 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 28011
# 	   - ND: 26370
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n20_DFnet.txt
#
# 	 - Detected: 46458 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 20706
# 	   - ND: 25752
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n21_DFnet.txt
#
# 	 - Detected: 53850 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27400
# 	   - ND: 26450
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n22_DFnet.txt
#
# 	 - Detected: 51130 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25551
# 	   - ND: 25579
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n23_DFnet.txt
#
# 	 - Detected: 46784 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 22500
# 	   - ND: 24284
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n24_DFnet.txt
#
# 	 - Detected: 53405 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26106
# 	   - ND: 27299
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n25_DFnet.txt
#
# 	 - Detected: 50153 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23127
# 	   - ND: 27026
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n26_DFnet.txt
#
# 	 - Detected: 52179 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24414
# 	   - ND: 27765
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n27_DFnet.txt
#
# 	 - Detected: 53068 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26230
# 	   - ND: 26838
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n28_DFnet.txt
#
# 	 - Detected: 50625 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26003
# 	   - ND: 24622
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n29_DFnet.txt
#
# 	 - Detected: 49523 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26889
# 	   - ND: 22634
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n3_DFnet.txt
#
# 	 - Detected: 47406 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24988
# 	   - ND: 22418
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n30_DFnet.txt
#
# 	 - Detected: 48482 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 22784
# 	   - ND: 25698
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n31_DFnet.txt
#
# 	 - Detected: 48605 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23129
# 	   - ND: 25476
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n32_DFnet.txt
#
# 	 - Detected: 51465 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26595
# 	   - ND: 24870
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n33_DFnet.txt
#
# 	 - Detected: 49580 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 21540
# 	   - ND: 28040
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n34_DFnet.txt
#
# 	 - Detected: 51824 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24844
# 	   - ND: 26980
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n35_DFnet.txt
#
# 	 - Detected: 51344 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26661
# 	   - ND: 24683
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n36_DFnet.txt
#
# 	 - Detected: 52652 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26498
# 	   - ND: 26154
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n37_DFnet.txt
#
# 	 - Detected: 52300 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25380
# 	   - ND: 26920
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n38_DFnet.txt
#
# 	 - Detected: 52074 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27538
# 	   - ND: 24536
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n39_DFnet.txt
#
# 	 - Detected: 53094 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27519
# 	   - ND: 25575
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n4_DFnet.txt
#
# 	 - Detected: 51854 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25896
# 	   - ND: 25958
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n40_DFnet.txt
#
# 	 - Detected: 51342 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26196
# 	   - ND: 25146
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n41_DFnet.txt
#
# 	 - Detected: 51896 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25094
# 	   - ND: 26802
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n42_DFnet.txt
#
# 	 - Detected: 53391 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26373
# 	   - ND: 27018
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n43_DFnet.txt
#
# 	 - Detected: 50568 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27643
# 	   - ND: 22925
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n44_DFnet.txt
#
# 	 - Detected: 47506 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 20494
# 	   - ND: 27012
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n45_DFnet.txt
#
# 	 - Detected: 49667 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25875
# 	   - ND: 23792
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n46_DFnet.txt
#
# 	 - Detected: 51375 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25468
# 	   - ND: 25907
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n47_DFnet.txt
#
# 	 - Detected: 52510 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26800
# 	   - ND: 25710
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n48_DFnet.txt
#
# 	 - Detected: 45612 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 18984
# 	   - ND: 26628
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n49_DFnet.txt
#
# 	 - Detected: 47119 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 22306
# 	   - ND: 24813
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n5_DFnet.txt
#
# 	 - Detected: 48921 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23678
# 	   - ND: 25243
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n50_DFnet.txt
#
# 	 - Detected: 50987 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25446
# 	   - ND: 25541
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n51_DFnet.txt
#
# 	 - Detected: 50221 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24723
# 	   - ND: 25498
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n52_DFnet.txt
#
# 	 - Detected: 48377 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 22704
# 	   - ND: 25673
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#  - Processing: CellChat_Permutation_n53_DFnet.txt
#
# 	 - Detected: 52021 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 28080
# 	   - ND: 23941
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n54_DFnet.txt
#
# 	 - Detected: 50989 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24098
# 	   - ND: 26891
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n55_DFnet.txt
#
# 	 - Detected: 48471 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25930
# 	   - ND: 22541
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n56_DFnet.txt
#
# 	 - Detected: 51775 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23839
# 	   - ND: 27936
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n57_DFnet.txt
#
# 	 - Detected: 48878 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25396
# 	   - ND: 23482
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n58_DFnet.txt
#
# 	 - Detected: 50853 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23474
# 	   - ND: 27379
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n59_DFnet.txt
#
# 	 - Detected: 53114 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27514
# 	   - ND: 25600
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n6_DFnet.txt
#
# 	 - Detected: 49998 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24380
# 	   - ND: 25618
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n60_DFnet.txt
#
# 	 - Detected: 48567 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23505
# 	   - ND: 25062
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n61_DFnet.txt
#
# 	 - Detected: 53253 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26823
# 	   - ND: 26430
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n62_DFnet.txt
#
# 	 - Detected: 52885 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24418
# 	   - ND: 28467
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n63_DFnet.txt
#
# 	 - Detected: 50752 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25735
# 	   - ND: 25017
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n64_DFnet.txt
#
# 	 - Detected: 47972 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 21042
# 	   - ND: 26930
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n65_DFnet.txt
#
# 	 - Detected: 53048 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25944
# 	   - ND: 27104
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n66_DFnet.txt
#
# 	 - Detected: 51342 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26514
# 	   - ND: 24828
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n67_DFnet.txt
#
# 	 - Detected: 50427 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24952
# 	   - ND: 25475
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n68_DFnet.txt
#
# 	 - Detected: 50723 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24926
# 	   - ND: 25797
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n69_DFnet.txt
#
# 	 - Detected: 51178 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26755
# 	   - ND: 24423
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n7_DFnet.txt
#
# 	 - Detected: 53856 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25243
# 	   - ND: 28613
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n70_DFnet.txt
#
# 	 - Detected: 44259 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 19641
# 	   - ND: 24618
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n71_DFnet.txt
#
# 	 - Detected: 53257 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27132
# 	   - ND: 26125
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n72_DFnet.txt
#
# 	 - Detected: 48093 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25919
# 	   - ND: 22174
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n73_DFnet.txt
#
# 	 - Detected: 51285 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25693
# 	   - ND: 25592
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n74_DFnet.txt
#
# 	 - Detected: 51585 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25570
# 	   - ND: 26015
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n75_DFnet.txt
#
# 	 - Detected: 48998 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24220
# 	   - ND: 24778
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n76_DFnet.txt
#
# 	 - Detected: 53264 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27089
# 	   - ND: 26175
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n77_DFnet.txt
#
# 	 - Detected: 44976 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 17962
# 	   - ND: 27014
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n78_DFnet.txt
#
# 	 - Detected: 51834 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24468
# 	   - ND: 27366
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n79_DFnet.txt
#
# 	 - Detected: 47377 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 20481
# 	   - ND: 26896
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n8_DFnet.txt
#
# 	 - Detected: 52129 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26709
# 	   - ND: 25420
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n80_DFnet.txt
#
# 	 - Detected: 48234 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23382
# 	   - ND: 24852
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n81_DFnet.txt
#
# 	 - Detected: 52749 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23397
# 	   - ND: 29352
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n82_DFnet.txt
#
# 	 - Detected: 47878 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 21088
# 	   - ND: 26790
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n83_DFnet.txt
#
# 	 - Detected: 51730 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25491
# 	   - ND: 26239
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n84_DFnet.txt
#
# 	 - Detected: 49320 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 22378
# 	   - ND: 26942
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n85_DFnet.txt
#
# 	 - Detected: 51674 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24463
# 	   - ND: 27211
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n86_DFnet.txt
#
# 	 - Detected: 47948 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 22224
# 	   - ND: 25724
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n87_DFnet.txt
#
# 	 - Detected: 49264 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23069
# 	   - ND: 26195
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n88_DFnet.txt
#
# 	 - Detected: 54237 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26855
# 	   - ND: 27382
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n89_DFnet.txt
#
# 	 - Detected: 48987 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26304
# 	   - ND: 22683
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n9_DFnet.txt
#
# 	 - Detected: 50084 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 23547
# 	   - ND: 26537
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n90_DFnet.txt
#
# 	 - Detected: 51774 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26889
# 	   - ND: 24885
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n91_DFnet.txt
#
# 	 - Detected: 48138 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24853
# 	   - ND: 23285
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n92_DFnet.txt
#
# 	 - Detected: 45523 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25286
# 	   - ND: 20237
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n93_DFnet.txt
#
# 	 - Detected: 53384 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 25088
# 	   - ND: 28296
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n94_DFnet.txt
#
# 	 - Detected: 51536 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26970
# 	   - ND: 24566
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n95_DFnet.txt
#
# 	 - Detected: 51224 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26586
# 	   - ND: 24638
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n96_DFnet.txt
#
# 	 - Detected: 51905 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 27120
# 	   - ND: 24785
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n97_DFnet.txt
#
# 	 - Detected: 52226 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 26576
# 	   - ND: 25650
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#  - Processing: CellChat_Permutation_n98_DFnet.txt
#
# 	 - Detected: 52340 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24931
# 	   - ND: 27409
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
#  - Processing: CellChat_Permutation_n99_DFnet.txt
#
# 	 - Detected: 52624 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - Aab: 24313
# 	   - ND: 28311
#
# 	 - Detected: 31481 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
#
# Comparing simulations against observations
#
# 	 - # Of null observed differential interactions (should be 0 for this analysis): 0
#
# 	 - Grabbing observed prob and pvalue:
# 	   - Aab: 27459
# 	   - ND: 27139
#
# 	 - Post subset for contrast interactions:
# 	   - Aab: 31481
# 	   - ND: 31481
# [1] "Processing T1D_early vs ND"
#  - Processing: CellChat_Permutation_n1_DFnet.txt
#
# 	 - Detected: 48584 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 26560
# 	   - ND: 22024
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n10_DFnet.txt
#
# 	 - Detected: 51077 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23769
# 	   - ND: 27308
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n100_DFnet.txt
#
# 	 - Detected: 50454 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23688
# 	   - ND: 26766
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n11_DFnet.txt
#
# 	 - Detected: 50369 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 22580
# 	   - ND: 27789
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n12_DFnet.txt
#
# 	 - Detected: 48290 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 24361
# 	   - ND: 23929
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n13_DFnet.txt
#
# 	 - Detected: 51764 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25616
# 	   - ND: 26148
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n14_DFnet.txt
#
# 	 - Detected: 49319 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23464
# 	   - ND: 25855
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n15_DFnet.txt
#
# 	 - Detected: 48282 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 22387
# 	   - ND: 25895
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n16_DFnet.txt
#
# 	 - Detected: 44743 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 19372
# 	   - ND: 25371
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n17_DFnet.txt
#
# 	 - Detected: 48163 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 24999
# 	   - ND: 23164
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n18_DFnet.txt
#
# 	 - Detected: 53674 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 27079
# 	   - ND: 26595
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n19_DFnet.txt
#
# 	 - Detected: 46774 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 19549
# 	   - ND: 27225
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n2_DFnet.txt
#
# 	 - Detected: 46966 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 20596
# 	   - ND: 26370
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n20_DFnet.txt
#
# 	 - Detected: 53579 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 27827
# 	   - ND: 25752
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n21_DFnet.txt
#
# 	 - Detected: 46423 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 19973
# 	   - ND: 26450
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n22_DFnet.txt
#
# 	 - Detected: 51841 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 26262
# 	   - ND: 25579
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n23_DFnet.txt
#
# 	 - Detected: 51258 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 26974
# 	   - ND: 24284
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n24_DFnet.txt
#
# 	 - Detected: 46870 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 19571
# 	   - ND: 27299
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n25_DFnet.txt
#
# 	 - Detected: 49806 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 22780
# 	   - ND: 27026
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n26_DFnet.txt
#
# 	 - Detected: 52716 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 24951
# 	   - ND: 27765
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n27_DFnet.txt
#
# 	 - Detected: 48658 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 21820
# 	   - ND: 26838
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n28_DFnet.txt
#
# 	 - Detected: 49825 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25203
# 	   - ND: 24622
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n29_DFnet.txt
#
# 	 - Detected: 49615 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 26981
# 	   - ND: 22634
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n3_DFnet.txt
#
# 	 - Detected: 48098 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25680
# 	   - ND: 22418
#
# 	 - Detected: 29393 unique interactions from the observations
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n30_DFnet.txt
#
# 	 - Detected: 48439 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 22741
# 	   - ND: 25698
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n31_DFnet.txt
#
# 	 - Detected: 50950 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25474
# 	   - ND: 25476
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n32_DFnet.txt
#
# 	 - Detected: 50521 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25651
# 	   - ND: 24870
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n33_DFnet.txt
#
# 	 - Detected: 47906 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 19866
# 	   - ND: 28040
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n34_DFnet.txt
#
# 	 - Detected: 45599 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 18619
# 	   - ND: 26980
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n35_DFnet.txt
#
# 	 - Detected: 47486 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 22803
# 	   - ND: 24683
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n36_DFnet.txt
#
# 	 - Detected: 46646 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 20492
# 	   - ND: 26154
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n37_DFnet.txt
#
# 	 - Detected: 51308 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 24388
# 	   - ND: 26920
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n38_DFnet.txt
#
# 	 - Detected: 49559 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25023
# 	   - ND: 24536
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n39_DFnet.txt
#
# 	 - Detected: 48731 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23156
# 	   - ND: 25575
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n4_DFnet.txt
#
# 	 - Detected: 48393 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 22435
# 	   - ND: 25958
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n40_DFnet.txt
#
# 	 - Detected: 49056 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23910
# 	   - ND: 25146
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n41_DFnet.txt
#
# 	 - Detected: 50580 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23778
# 	   - ND: 26802
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n42_DFnet.txt
#
# 	 - Detected: 51141 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 24123
# 	   - ND: 27018
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n43_DFnet.txt
#
# 	 - Detected: 48428 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 25503
# 	   - ND: 22925
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n44_DFnet.txt
#
# 	 - Detected: 50213 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23201
# 	   - ND: 27012
#
# 	 - Detected: 29393 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_early: 29393
# 	   - ND: 29393
#
#  - Processing: CellChat_Permutation_n45_DFnet.txt
#
# 	 - Detected: 46888 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_early: 23096
# 	   - ND: 23792
#
# 	 - Detected: 29393 unique interactions from the observations
#
# ...
# 	   - ND: 27379
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n59_DFnet.txt
#
# 	 - Detected: 50307 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24707
# 	   - ND: 25600
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n6_DFnet.txt
#
# 	 - Detected: 51954 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 26336
# 	   - ND: 25618
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n60_DFnet.txt
#
# 	 - Detected: 53193 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 28131
# 	   - ND: 25062
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n61_DFnet.txt
#
# 	 - Detected: 50123 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23693
# 	   - ND: 26430
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n62_DFnet.txt
#
# 	 - Detected: 50881 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 22414
# 	   - ND: 28467
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n63_DFnet.txt
#
# 	 - Detected: 48634 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23617
# 	   - ND: 25017
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n64_DFnet.txt
#
# 	 - Detected: 51983 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25053
# 	   - ND: 26930
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n65_DFnet.txt
#
# 	 - Detected: 53013 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25909
# 	   - ND: 27104
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n66_DFnet.txt
#
# 	 - Detected: 49504 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24676
# 	   - ND: 24828
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n67_DFnet.txt
#
# 	 - Detected: 52213 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 26738
# 	   - ND: 25475
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n68_DFnet.txt
#
# 	 - Detected: 50511 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24714
# 	   - ND: 25797
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n69_DFnet.txt
#
# 	 - Detected: 48051 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23628
# 	   - ND: 24423
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n7_DFnet.txt
#
# 	 - Detected: 53253 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24640
# 	   - ND: 28613
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n70_DFnet.txt
#
# 	 - Detected: 50586 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25968
# 	   - ND: 24618
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n71_DFnet.txt
#
# 	 - Detected: 49720 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23595
# 	   - ND: 26125
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n72_DFnet.txt
#
# 	 - Detected: 48101 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25927
# 	   - ND: 22174
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n73_DFnet.txt
#
# 	 - Detected: 50067 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24475
# 	   - ND: 25592
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#  - Processing: CellChat_Permutation_n74_DFnet.txt
#
# 	 - Detected: 51757 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25742
# 	   - ND: 26015
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n75_DFnet.txt
#
# 	 - Detected: 51426 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 26648
# 	   - ND: 24778
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n76_DFnet.txt
#
# 	 - Detected: 49605 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23430
# 	   - ND: 26175
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n77_DFnet.txt
#
# 	 - Detected: 52106 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25092
# 	   - ND: 27014
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n78_DFnet.txt
#
# 	 - Detected: 50920 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23554
# 	   - ND: 27366
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n79_DFnet.txt
#
# 	 - Detected: 52724 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25828
# 	   - ND: 26896
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n8_DFnet.txt
#
# 	 - Detected: 50262 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24842
# 	   - ND: 25420
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n80_DFnet.txt
#
# 	 - Detected: 52125 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 27273
# 	   - ND: 24852
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n81_DFnet.txt
#
# 	 - Detected: 52762 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23410
# 	   - ND: 29352
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n82_DFnet.txt
#
# 	 - Detected: 50652 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23862
# 	   - ND: 26790
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n83_DFnet.txt
#
# 	 - Detected: 52516 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 26277
# 	   - ND: 26239
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n84_DFnet.txt
#
# 	 - Detected: 52187 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25245
# 	   - ND: 26942
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n85_DFnet.txt
#
# 	 - Detected: 52165 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24954
# 	   - ND: 27211
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n86_DFnet.txt
#
# 	 - Detected: 52512 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 26788
# 	   - ND: 25724
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n87_DFnet.txt
#
# 	 - Detected: 52011 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25816
# 	   - ND: 26195
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n88_DFnet.txt
#
# 	 - Detected: 51867 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24485
# 	   - ND: 27382
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n89_DFnet.txt
#
# 	 - Detected: 47026 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24343
# 	   - ND: 22683
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n9_DFnet.txt
#
# 	 - Detected: 49008 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 22471
# 	   - ND: 26537
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n90_DFnet.txt
#
# 	 - Detected: 50886 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 26001
# 	   - ND: 24885
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n91_DFnet.txt
#
# 	 - Detected: 47377 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24092
# 	   - ND: 23285
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n92_DFnet.txt
#
# 	 - Detected: 44524 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24287
# 	   - ND: 20237
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n93_DFnet.txt
#
# 	 - Detected: 51895 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23599
# 	   - ND: 28296
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n94_DFnet.txt
#
# 	 - Detected: 48255 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23689
# 	   - ND: 24566
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n95_DFnet.txt
#
# 	 - Detected: 50544 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 25906
# 	   - ND: 24638
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#  - Processing: CellChat_Permutation_n96_DFnet.txt
#
# 	 - Detected: 48746 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23961
# 	   - ND: 24785
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n97_DFnet.txt
#
# 	 - Detected: 48528 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 22878
# 	   - ND: 25650
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n98_DFnet.txt
#
# 	 - Detected: 52148 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 24739
# 	   - ND: 27409
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
#  - Processing: CellChat_Permutation_n99_DFnet.txt
#
# 	 - Detected: 51978 significant interactions in contrast
#
# 	 - Distribution of interactions:
# 	   - T1D_late: 23667
# 	   - ND: 28311
#
# 	 - Detected: 28644 unique interactions from the observations
#
# 	 - Check that contrasts have same number of interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644
#
# Comparing simulations against observations
#
# 	 - # Of null observed differential interactions (should be 0 for this analysis): 0
#
# 	 - Grabbing observed prob and pvalue:
# 	   - T1D_late: 14873
# 	   - ND: 27139
#
# 	 - Post subset for contrast interactions:
# 	   - T1D_late: 28644
# 	   - ND: 28644

# %%
tail(contrast.stats.1, n = 4)
tail(contrast.stats.2, n = 4)
tail(diff.analysis, n = 4)
# Out:
#                                  interaction.id                   condition FDR prob
# Tcells--Tcells--WNT7A--FZD5_LRP5 Tcells--Tcells--WNT7A--FZD5_LRP5 T1D_late  NA  NA
# Tcells--Tcells--WNT7A--FZD5_LRP6 Tcells--Tcells--WNT7A--FZD5_LRP6 T1D_late  NA  NA
# Tcells--Tcells--WNT7A--FZD6_LRP5 Tcells--Tcells--WNT7A--FZD6_LRP5 T1D_late  NA  NA
# Tcells--Tcells--WNT7A--FZD6_LRP6 Tcells--Tcells--WNT7A--FZD6_LRP6 T1D_late  NA  NA
#                                  interaction.id                   condition FDR        prob
# Tcells--Tcells--WNT7A--FZD5_LRP5 Tcells--Tcells--WNT7A--FZD5_LRP5 ND        0.00153715 0.00002393793
# Tcells--Tcells--WNT7A--FZD5_LRP6 Tcells--Tcells--WNT7A--FZD5_LRP6 ND        0.00153715 0.00002011978
# Tcells--Tcells--WNT7A--FZD6_LRP5 Tcells--Tcells--WNT7A--FZD6_LRP5 ND        0.00153715 0.00006142525
# Tcells--Tcells--WNT7A--FZD6_LRP6 Tcells--Tcells--WNT7A--FZD6_LRP6 ND        0.00153715 0.00005162811
#                                  interaction.id                   condition stars
# Tcells--Tcells--WNT7A--FZD5_LRP5 Tcells--Tcells--WNT7A--FZD5_LRP5 T1D_late
# Tcells--Tcells--WNT7A--FZD5_LRP6 Tcells--Tcells--WNT7A--FZD5_LRP6 T1D_late
# Tcells--Tcells--WNT7A--FZD6_LRP5 Tcells--Tcells--WNT7A--FZD6_LRP5 T1D_late
# Tcells--Tcells--WNT7A--FZD6_LRP6 Tcells--Tcells--WNT7A--FZD6_LRP6 T1D_late

# %% [markdown]
# # Create Differential analysis consensus

# %%
# Pull differential results together
diff.analysis.ls = list()
diff.analysis = NULL

for (i in seq_along(diff.analysis.dir.ls)){
     data.use = read.table(diff.analysis.dir.ls[i], sep = "\t", stringsAsFactors = F, header = T)
     message("Interactions detected in contrast ", levels(factor(data.use$contrasts)), ": ", nrow(data.use))
     diff.analysis = rbind(diff.analysis, data.use)
}
message("Total number of interactions: ", nrow(diff.analysis), " - Check that sum is correct")
# Remove interactions where entire celltpes/condtion are not present
# AAB.cell.blacklist = c("")
ETD.cell.blacklist = c("MUC5b_Ductal")
LTD.cell.blacklist = c("Delta", "Tcells")

diff.analysis <- diff.analysis %>%
  filter(!((target %in% ETD.cell.blacklist | source %in% ETD.cell.blacklist) 
           & obs.contrast1.condition == condition.ls[3]))

diff.analysis <- diff.analysis %>%
  filter(!((target %in% LTD.cell.blacklist | source %in% LTD.cell.blacklist) 
           & obs.contrast1.condition == condition.ls[4]))

message("Interactions post blacklist: ", nrow(diff.analysis))

# Add annotation
diff.analysis = merge(diff.analysis, ligands.GDB, by = "ligand")
# Save
file.name = paste(results.dir, "ALL_Differential_analysis_Consensus.txt", sep = "")
write.table(diff.analysis, file.name, sep = "\t", quote = F, col.names=T, row.names = T)

# Subset to just have differential interactions
diff.analysis.sig = diff.analysis[!diff.analysis$stars == "",]
# message("Number of differential interactions: ", nrow(diff.analysis.sig))

# FDR correction
diff.analysis.sig$contrast.pvalue[diff.analysis.sig$contrast.pvalue == 0] = 0.001
diff.analysis.sig$contrast.FDR = p.adjust(diff.analysis.sig$contrast.pvalue, 'BH')
diff.analysis.sig = diff.analysis.sig[diff.analysis.sig$contrast.FDR < 0.1,]
message("Number of differential interactions (FDR < 0.1): ", nrow(diff.analysis.sig))
message(" - ND vs AAB: ", nrow(diff.analysis.sig[diff.analysis.sig$obs.contrast1.condition == condition.ls[2], ]))
message(" - ND vs ETD: ", nrow(diff.analysis.sig[diff.analysis.sig$obs.contrast1.condition == condition.ls[3], ]))
message(" - ND vs LTD: ", nrow(diff.analysis.sig[diff.analysis.sig$obs.contrast1.condition == condition.ls[4], ]))
# Out:
# Interactions detected in contrast Aab.Vs.ND: 31481
#
# Interactions detected in contrast T1D_early.Vs.ND: 29393
#
# Interactions detected in contrast T1D_late.Vs.ND: 28644
#
# Total number of interactions: 89518 - Check that sum is correct
#
# Interactions post blacklist: 79011
#
# Number of differential interactions (FDR < 0.1): 6042
#
#  - ND vs AAB: 530
#
#  - ND vs ETD: 2410
#
#  - ND vs LTD: 3102

# %%
# Assign compartments
diff.analysis.sig$compartment.source = diff.analysis.sig$source

diff.analysis.sig$compartment.source = ifelse(diff.analysis.sig$compartment.source %in%  Endocrine, "Endocrine", 
                 ifelse(diff.analysis.sig$compartment.source %in%  Exocrine, "Exocrine",
                        ifelse(diff.analysis.sig$compartment.source %in%  Immune, "Immune",
                               ifelse(diff.analysis.sig$compartment.source %in%  Endothelial, "Endothelial", "Stromal"))))

diff.analysis.sig$compartment.source = factor(diff.analysis.sig$compartment.source, levels = c('Endocrine','Exocrine','Immune','Endothelial', "Stromal"))
diff.analysis.sig = diff.analysis.sig[!is.na(diff.analysis.sig$compartment.source),]

# Assign compartments
diff.analysis.sig$compartment.target = diff.analysis.sig$target

diff.analysis.sig$compartment.target = ifelse(diff.analysis.sig$compartment.target %in%  Endocrine, "Endocrine", 
                 ifelse(diff.analysis.sig$compartment.target %in%  Exocrine, "Exocrine",
                        ifelse(diff.analysis.sig$compartment.target %in%  Immune, "Immune",
                               ifelse(diff.analysis.sig$compartment.target %in%  Endothelial, "Endothelial", "Stromal"))))

diff.analysis.sig$compartment.target = factor(diff.analysis.sig$compartment.target, levels = c('Endocrine','Exocrine','Immune','Endothelial', "Stromal"))
diff.analysis.sig = diff.analysis.sig[!is.na(diff.analysis.sig$compartment.target),]
diff.analysis.sig = diff.analysis.sig[!is.na(diff.analysis.sig$compartment.source),]

# %%
nrow(diff.analysis.sig)
# Out:
# [1] 6042

# %%
# factorize stuff
diff.analysis.sig$contrasts = factor(diff.analysis.sig$contrasts, levels = c('T1D_late.Vs.ND', 
                                                                             'T1D_early.Vs.ND', 'Aab.Vs.ND'))
diff.analysis.sig$target = factor(diff.analysis.sig$target, levels = cell.pop.order)
diff.analysis.sig$source = factor(diff.analysis.sig$source, levels = cell.pop.order)
diff.analysis.sig$obs.contrast1.condition = factor(diff.analysis.sig$obs.contrast1.condition, levels = c(condition.ls))
diff.analysis.sig$Interaction.type = factor(diff.analysis.sig$Mode.of.Action, levels = c(Interaction.type.ls))
diff.analysis.sig$Interaction.type = factor(diff.analysis.sig$Mode.of.Action, levels = c(Interaction.type.ls))
# diff.analysis.sig$Functional.classification = factor(diff.analysis.sig$Functional.classification, levels = rev(Functional.classification.order))

# %%
# take lowest value possible
min = min(min(diff.analysis.sig$obs.contrast1.prob, na.rm = TRUE), min(diff.analysis.sig$obs.contrast2.prob, na.rm = TRUE))
# backup real prob
diff.analysis.sig$obs.contrast1.prob[is.na(diff.analysis.sig$obs.contrast1.prob)] = 0
diff.analysis.sig$obs.contrast2.prob[is.na(diff.analysis.sig$obs.contrast2.prob)] = 0
diff.analysis.sig$obs.contrast1.prob.fc = diff.analysis.sig$obs.contrast1.prob
diff.analysis.sig$obs.contrast2.prob.fc = diff.analysis.sig$obs.contrast2.prob
## Add fold change column
message(" - Min: ", min)
# Add that value as a pseudocount
diff.analysis.sig$obs.contrast1.prob.fc = diff.analysis.sig$obs.contrast1.prob.fc + min
diff.analysis.sig$obs.contrast2.prob.fc = diff.analysis.sig$obs.contrast2.prob.fc + min
# Out:
#  - Min: 0.00001803090679968

# %%
message(" - Min: ", min(diff.analysis.sig$obs.contrast1.prob.fc, na.rm = TRUE))
nrow(diff.analysis.sig)
diff.analysis.sig = diff.analysis.sig[rowSums(is.na(diff.analysis.sig)) != ncol(diff.analysis.sig), ]
nrow(diff.analysis.sig)
diff.analysis.sig$foldchange = log(diff.analysis.sig$obs.contrast1.prob.fc/diff.analysis.sig$obs.contrast2.prob.fc)
# Note up and down-regulated interactions
diff.analysis.sig$direction = diff.analysis.sig$foldchange
diff.analysis.sig$direction = ifelse(diff.analysis.sig$foldchange > 0, "UP", "DOWN")
# Out:
#  - Min: 0.00001803090679968
# [1] 6042
# [1] 6042

# %%
file.name = paste(results.dir, "Differential_analysis_Consensus.txt", sep = "")
write.table(diff.analysis.sig, file.name, sep = "\t", quote = F, col.names=T, row.names = T)

# %%
diff.analysis.sig[diff.analysis.sig$source == "Tcells" & diff.analysis.sig$foldchange < 0,]
# Out:
#       ligand interaction.id                                   source target             receptor       obs.contrast1.condition obs.contrast2.condition contrasts       obs.contrast1.FDR obs.contrast2.FDR ⋯ Functional.sub.classification Gene.Family     contrast.FDR compartment.source compartment.target Interaction.type   obs.contrast1.prob.fc obs.contrast2.prob.fc foldchange direction
# 5900  CADM1  Tcells--Quiescent_Stellate--CADM1--CADM1         Tcells Quiescent_Stellate CADM1          Aab                     ND                      Aab.Vs.ND               NA        0.02832550        ⋯ Other Cell Adhesion Proteins  -               0.050000000  Immune             Stromal            Cell-Cell Contact  0.00001803091         0.00048465557         -3.2913511 DOWN
# 5928  CADM1  Tcells--Quiescent_Stellate--CADM1--CADM1         Tcells Quiescent_Stellate CADM1          T1D_early               ND                      T1D_early.Vs.ND         NA        0.02832550        ⋯ Other Cell Adhesion Proteins  -               0.040999774  Immune             Stromal            Cell-Cell Contact  0.00001803091         0.00048465557         -3.2913511 DOWN
# 7054  CD6    Tcells--Quiescent_Stellate--CD6--ALCAM           Tcells Quiescent_Stellate ALCAM          T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ Stimulatory Molecules         CD Family       0.050000000  Immune             Stromal            Cell-Cell Contact  0.00001803091         0.00306601013         -5.1360450 DOWN
# 32253 IL24   Tcells--Acinar_3--IL24--IL22RA1_IL20RB           Tcells Acinar_3           IL22RA1_IL20RB Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Interleukins                  IL-10 Family    0.050000000  Immune             Exocrine           Secreted Signaling 0.00001803091         0.00004635896         -0.9443273 DOWN
# 32261 IL24   Tcells--Quiescent_Stellate--IL24--IL22RA1_IL20RB Tcells Quiescent_Stellate IL22RA1_IL20RB Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Interleukins                  IL-10 Family    0.040999774  Immune             Stromal            Secreted Signaling 0.00001803091         0.00003867027         -0.7629838 DOWN
# 44714 LAMB2  Tcells--Endothelial--LAMB2--ITGA7_ITGB1          Tcells Endothelial        ITGA7_ITGB1    Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Laminins                      Laminin Family  0.040999774  Immune             Endothelial        ECM-Receptor       0.00001803091         0.00005600646         -1.1333797 DOWN
# 44801 LAMB2  Tcells--Acinar_5--LAMB2--ITGA7_ITGB1             Tcells Acinar_5           ITGA7_ITGB1    Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Laminins                      Laminin Family  0.050000000  Immune             Exocrine           ECM-Receptor       0.00001803091         0.00005435344         -1.1034206 DOWN
# 45336 LAMB2  Tcells--Delta--LAMB2--ITGA7_ITGB1                Tcells Delta              ITGA7_ITGB1    Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Laminins                      Laminin Family  0.050000000  Immune             Endocrine          ECM-Receptor       0.00001803091         0.00008874897         -1.5937245 DOWN
# 58929 SELL   Tcells--Macrophage--SELL--CD34                   Tcells Macrophage         CD34           Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Selectins                     Selectin Family 0.033390439  Immune             Immune             Cell-Cell Contact  0.00001803091         0.00005067335         -1.0333128 DOWN
# 58934 SELL   Tcells--Quiescent_Stellate--SELL--PODXL          Tcells Quiescent_Stellate PODXL          Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Selectins                     Selectin Family 0.033390439  Immune             Stromal            Cell-Cell Contact  0.00001803091         0.00037523226         -3.0354579 DOWN
# 58992 SELL   Tcells--Quiescent_Stellate--SELL--PODXL          Tcells Quiescent_Stellate PODXL          T1D_early               ND                      T1D_early.Vs.ND 0.04163355        0.00153715        ⋯ Selectins                     Selectin Family 0.040999774  Immune             Stromal            Cell-Cell Contact  0.00003752357         0.00037523226         -2.3025759 DOWN
# 59012 SELPLG Tcells--Tcells--SELPLG--SELL                     Tcells Tcells             SELL           Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ Selectins                     Selectin Family 0.050000000  Immune             Immune             Cell-Cell Contact  0.00001803091         0.00024937780         -2.6268817 DOWN
# 62837 SEMA4D Tcells--Acinar_5--SEMA4D--PLXNB2                 Tcells Acinar_5           PLXNB2         T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ Semaphorins                   Semaphorins     0.022107574  Immune             Exocrine           Cell-Cell Contact  0.00001803091         0.00044355684         -3.2027386 DOWN
# 62865 SEMA4D Tcells--Acinar_5--SEMA4D--PLXNB1                 Tcells Acinar_5           PLXNB1         T1D_early               ND                      T1D_early.Vs.ND 0.00153715        0.00153715        ⋯ Semaphorins                   Semaphorins     0.022107574  Immune             Exocrine           Cell-Cell Contact  0.00009003431         0.00139712932         -2.7419840 DOWN
# 77312 WNT7A  Tcells--Endothelial--WNT7A--FZD5_LRP6            Tcells Endothelial        FZD5_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.022107574  Immune             Endothelial        Secreted Signaling 0.00001803091         0.00006670480         -1.3081896 DOWN
# 77383 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD3_LRP5     Tcells Quiescent_Stellate FZD3_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00008259123         -1.5218162 DOWN
# 77388 WNT7A  Tcells--Activated_Stellate--WNT7A--FZD10_LRP6    Tcells Activated_Stellate FZD10_LRP6     Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.046166189  Immune             Stromal            Secreted Signaling 0.00001803091         0.00003765853         -0.7364721 DOWN
# 77400 WNT7A  Tcells--Acinar_4--WNT7A--FZD2_LRP6               Tcells Acinar_4           FZD2_LRP6      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.022107574  Immune             Exocrine           Secreted Signaling 0.00001803091         0.00004587623         -0.9338597 DOWN
# 77438 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD2_LRP5     Tcells Quiescent_Stellate FZD2_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00005031211         -1.0261585 DOWN
# 77445 WNT7A  Tcells--Endothelial--WNT7A--FZD5_LRP5            Tcells Endothelial        FZD5_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.022107574  Immune             Endothelial        Secreted Signaling 0.00001803091         0.00006435230         -1.2722854 DOWN
# 77460 WNT7A  Tcells--Macrophage--WNT7A--FZD4_LRP5             Tcells Macrophage         FZD4_LRP5      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Immune             Secreted Signaling 0.00001803091         0.00004824247         -0.9841525 DOWN
# 77494 WNT7A  Tcells--Alpha--WNT7A--FZD4_LRP5                  Tcells Alpha              FZD4_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00003858203         -0.7606993 DOWN
# 77507 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD3_LRP6     Tcells Quiescent_Stellate FZD3_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00009356152         -1.6465319 DOWN
# 77549 WNT7A  Tcells--Delta--WNT7A--FZD7_LRP6                  Tcells Delta              FZD7_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00007626561         -1.4421348 DOWN
# 77552 WNT7A  Tcells--Delta--WNT7A--FZD8_LRP5                  Tcells Delta              FZD8_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.040999774  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00010194355         -1.7323319 DOWN
# 77565 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD4_LRP6     Tcells Quiescent_Stellate FZD4_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00018156641         -2.3095341 DOWN
# 77566 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD5_LRP6     Tcells Quiescent_Stellate FZD5_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00006557698         -1.2911374 DOWN
# 77568 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD5_LRP5     Tcells Quiescent_Stellate FZD5_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00005867109         -1.1798597 DOWN
# 77574 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD2_LRP6     Tcells Quiescent_Stellate FZD2_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.046166189  Immune             Stromal            Secreted Signaling 0.00001803091         0.00005579764         -1.1296443 DOWN
# 77580 WNT7A  Tcells--Acinar_3--WNT7A--FZD1_LRP5               Tcells Acinar_3           FZD1_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Exocrine           Secreted Signaling 0.00001803091         0.00003985554         -0.7931741 DOWN
# 77582 WNT7A  Tcells--Beta--WNT7A--FZD4_LRP5                   Tcells Beta               FZD4_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00005922280         -1.1892192 DOWN
# 77594 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD5_LRP6     Tcells Quiescent_Stellate FZD5_LRP6      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.040999774  Immune             Stromal            Secreted Signaling 0.00001803091         0.00006557698         -1.2911374 DOWN
# 77621 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD5_LRP5     Tcells Quiescent_Stellate FZD5_LRP5      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Stromal            Secreted Signaling 0.00001803091         0.00005867109         -1.1798597 DOWN
# 77628 WNT7A  Tcells--Macrophage--WNT7A--FZD4_LRP6             Tcells Macrophage         FZD4_LRP6      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Immune             Secreted Signaling 0.00001803091         0.00004282659         -0.8650719 DOWN
# 77650 WNT7A  Tcells--Beta--WNT7A--FZD4_LRP6                   Tcells Beta               FZD4_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00004890644         -0.9978217 DOWN
# 77656 WNT7A  Tcells--Alpha--WNT7A--FZD1_LRP5                  Tcells Alpha              FZD1_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.040999774  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00003858203         -0.7606993 DOWN
# 77672 WNT7A  Tcells--Alpha--WNT7A--FZD1_LRP6                  Tcells Alpha              FZD1_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.040999774  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00004025545         -0.8031582 DOWN
# 77673 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD3_LRP5     Tcells Quiescent_Stellate FZD3_LRP5      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00008259123         -1.5218162 DOWN
# 77674 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD4_LRP5     Tcells Quiescent_Stellate FZD4_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00015781582         -2.1693413 DOWN
# 77684 WNT7A  Tcells--Activated_Stellate--WNT7A--FZD10_LRP6    Tcells Activated_Stellate FZD10_LRP6     T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Stromal            Secreted Signaling 0.00001803091         0.00003765853         -0.7364721 DOWN
# 77685 WNT7A  Tcells--Macrophage--WNT7A--FZD4_LRP5             Tcells Macrophage         FZD4_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Immune             Secreted Signaling 0.00001803091         0.00004824247         -0.9841525 DOWN
# 77700 WNT7A  Tcells--Acinar_4--WNT7A--FZD2_LRP5               Tcells Acinar_4           FZD2_LRP5      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.022107574  Immune             Exocrine           Secreted Signaling 0.00001803091         0.00003746629         -0.7313544 DOWN
# 77709 WNT7A  Tcells--Delta--WNT7A--FZD7_LRP5                  Tcells Delta              FZD7_LRP5      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.046166189  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00008654635         -1.5685928 DOWN
# 77713 WNT7A  Tcells--Delta--WNT7A--FZD7_LRP5                  Tcells Delta              FZD7_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00008654635         -1.5685928 DOWN
# 77729 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD2_LRP6     Tcells Quiescent_Stellate FZD2_LRP6      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.022107574  Immune             Stromal            Secreted Signaling 0.00001803091         0.00005579764         -1.1296443 DOWN
# 77730 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD2_LRP5     Tcells Quiescent_Stellate FZD2_LRP5      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.003500579  Immune             Stromal            Secreted Signaling 0.00001803091         0.00005031211         -1.0261585 DOWN
# 77731 WNT7A  Tcells--Acinar_4--WNT7A--FZD2_LRP5               Tcells Acinar_4           FZD2_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Exocrine           Secreted Signaling 0.00001803091         0.00003746629         -0.7313544 DOWN
# 77732 WNT7A  Tcells--Acinar_3--WNT7A--FZD1_LRP6               Tcells Acinar_3           FZD1_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.046166189  Immune             Exocrine           Secreted Signaling 0.00001803091         0.00004965606         -1.0130332 DOWN
# 77740 WNT7A  Tcells--Quiescent_Stellate--WNT7A--FZD3_LRP6     Tcells Quiescent_Stellate FZD3_LRP6      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.033390439  Immune             Stromal            Secreted Signaling 0.00001803091         0.00009356152         -1.6465319 DOWN
# 77742 WNT7A  Tcells--Delta--WNT7A--FZD7_LRP6                  Tcells Delta              FZD7_LRP6      T1D_early               ND                      T1D_early.Vs.ND         NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.046166189  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00007626561         -1.4421348 DOWN
# 77744 WNT7A  Tcells--Macrophage--WNT7A--FZD1_LRP5             Tcells Macrophage         FZD1_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Immune             Secreted Signaling 0.00001803091         0.00005199912         -1.0591395 DOWN
# 77747 WNT7A  Tcells--Macrophage--WNT7A--FZD6_LRP5             Tcells Macrophage         FZD6_LRP5      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Immune             Secreted Signaling 0.00001803091         0.00006207929         -1.2363251 DOWN
# 77771 WNT7A  Tcells--Macrophage--WNT7A--FZD4_LRP6             Tcells Macrophage         FZD4_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Immune             Secreted Signaling 0.00001803091         0.00004282659         -0.8650719 DOWN
# 77772 WNT7A  Tcells--Delta--WNT7A--FZD8_LRP6                  Tcells Delta              FZD8_LRP6      Aab                     ND                      Aab.Vs.ND               NA        0.00153715        ⋯ WNT Signaling                 WNT Family      0.050000000  Immune             Endocrine          Secreted Signaling 0.00001803091         0.00008935263         -1.6005033 DOWN

# %% [markdown]
# # Differential interactions

# %% [markdown]
# ## number

# %%
# diff.analysis.sig = filter(diff.analysis.sig, Interaction.type != "ECM-Receptor" & Functional.classification != "ECM Proteins")

# %%
Differential.stats = as.data.frame(table(diff.analysis.sig$source, diff.analysis.sig$obs.contrast1.condition, diff.analysis.sig$foldchange > 0))
colnames(Differential.stats) = c("Celltype", "Condition", "Direction", "Freq")
Differential.stats = Differential.stats[!Differential.stats$Condition == "ND", ]
Differential.stats$Direction = gsub(x = Differential.stats$Direction, pattern = "TRUE", replacement = "UP")
Differential.stats$Direction = gsub(x = Differential.stats$Direction, pattern = "FALSE", replacement = "DOWN")
Differential.stats$Freq[Differential.stats$Direction == "DOWN"] <- -Differential.stats$Freq[Differential.stats$Direction == "DOWN"]

Differential.stats$Condition = factor(Differential.stats$Condition, levels = rev(c("Aab", "T1D_early", "T1D_late")))
Differential.stats = merge(Differential.stats, Cellpop.compartment, by = "Celltype")
max(Differential.stats$Freq)
min(Differential.stats$Freq)
head(Differential.stats, n=2)
# Out:
# [1] 372
# [1] -443
#   Celltype Condition Direction Freq compartment colors.compartments
# 1 Acinar_3 T1D_late  UP        28   Exocrine    #ed872d
# 2 Acinar_3 T1D_early UP        10   Exocrine    #ed872d

# %%
position = position_dodge(width = 0.8)

gg1 = ggplot(Differential.stats, aes(x = Celltype, y = Freq, label = Freq, fill = Condition)) +
    geom_bar(stat="identity", 
                     position = position, width = 0.7,
                     colour="black") +
            scale_fill_manual(values= colors.conditions)+
    labs(y= "\n Differential interaction vs ND", x = "", title = "Outgoing Signals") +
    theme_bw() +
    scale_y_continuous(limits = c(-400, 400),
                   breaks = c(-300, -150, 0, 150, 300),
                   labels = c("300" ,"150", "0", "150", "300"))+
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
                   legend.position = "none")+
    coord_flip()+
    facet_nested(rows = vars(compartment), 
             scales = "free", space = "free")

# %%
Differential.stats = as.data.frame(table(diff.analysis.sig$target, diff.analysis.sig$obs.contrast1.condition, diff.analysis.sig$foldchange > 0))
colnames(Differential.stats) = c("Celltype", "Condition", "Direction", "Freq")
Differential.stats = Differential.stats[!Differential.stats$Condition == "ND", ]
Differential.stats$Direction = gsub(x = Differential.stats$Direction, pattern = "TRUE", replacement = "UP")
Differential.stats$Direction = gsub(x = Differential.stats$Direction, pattern = "FALSE", replacement = "DOWN")
Differential.stats$Freq[Differential.stats$Direction == "DOWN"] <- -Differential.stats$Freq[Differential.stats$Direction == "DOWN"]

Differential.stats$Condition = factor(Differential.stats$Condition, levels = rev(c("Aab", "T1D_early", "T1D_late")))
Differential.stats = merge(Differential.stats, Cellpop.compartment, by = "Celltype")
max(Differential.stats$Freq)
min(Differential.stats$Freq)
head(Differential.stats, n=2)
# Out:
# [1] 304
# [1] -310
#   Celltype Condition Direction Freq compartment colors.compartments
# 1 Acinar_3 T1D_late  UP        60   Exocrine    #ed872d
# 2 Acinar_3 T1D_early UP        40   Exocrine    #ed872d

# %%
position = position_dodge(width = 0.8)

gg2 = ggplot(Differential.stats, aes(x = Celltype, y = Freq, label = Freq, fill = Condition)) +
    geom_bar(stat="identity", 
                     position = position, width = 0.7,
                     colour="black") +
            scale_fill_manual(values= colors.conditions)+
    labs(y= "\n Differential interaction vs ND", x = "", title = "Incoming Signals") +
    theme_bw() +
    scale_y_continuous(limits = c(-400, 400),
                   breaks = c(-300, -150, 0, 150, 300),
                   labels = c("300" ,"150", "0", "150", "300"))+
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
          legend.position = "none") + 
         coord_flip()+
    facet_nested(rows = vars(compartment), 
             scales = "free", space = "free")

# %%
options(repr.plot.width=15, repr.plot.height=12)
grid.arrange(gg1, gg2, nrow = 1, top = textGrob(paste("Cell-crosstalk changes across conditions"),
                                                            gp = gpar(fontsize = 20, fontface = "bold")))
# Out:
# Warning message:
# “Removed 1 rows containing missing values (`geom_bar()`).”
# plot without title

# %%
diff.analysis.sig.plot = diff.analysis.sig
# Make downregulated data become "-"
diff.analysis.sig.plot$obs.contrast1.prob[diff.analysis.sig.plot$direction == "DOWN"] <- -diff.analysis.sig.plot$obs.contrast1.prob[diff.analysis.sig.plot$direction == "DOWN"]

# %%
color_df <- data.frame(
  Functional.classification = c(
    'Hormones & Neuropeptides', 'Enzymes', 
    'Antigen-Presenting Molecules', 'Complement System', 'Immune regulators', 
    'Cell Adhesion Molecule', 'ECM Proteins', 'Modulators',
    'Growth Factors and Cytokines', 'Developmental Proteins'
  ),
  colors = c(
    '#4DA6FF', '#C0A2FF',  # Blue for Hormones & Neuropeptides, Darker Purple for Enzymes (Class 1)
    '#FF8C69', '#FF3300', '#FFA64D',  # Reds to Light Salmon for Class 2
    '#A67D5A', '#FFD700', 'white',  # Oranges to Light Yellow for Class 3
    '#8EFF89', '#66CDAA'  # Aquamarine and Medium Aquamarine for Class 4
  )
)

# Create a named vector from the dataframe
color_vector <- setNames(color_df$colors, color_df$Functional.classification)

# %%
gg1 = ggplot(diff.analysis.sig.plot, aes(x = contrasts, y = diff.obs, fill = Functional.classification)) +
  geom_bar(stat="identity", width = 0.7, colour="black") +
  labs(y= "\n IS", x = "", title = "Incoming Signals") +
  theme_bw() +
  theme(axis.text = element_text(size = 16),
        axis.title = element_text(size = 12, face = "bold"), 
        plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
        legend.position = "") + 
  coord_flip() +
  facet_nested(rows = vars(compartment.target, target), 
               scales = "free", space = "free") +
  scale_fill_manual(values = color_vector) 


gg2 = ggplot(diff.analysis.sig.plot, aes(x = contrasts, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7,
                     colour="black") +
    labs(y= "\n IS", x = "", title = "Outgoing Signals") +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
          legend.position = "") + 
         coord_flip()+
    facet_nested(rows = vars(compartment.source, source), 
             scales = "free", space = "free")+
  scale_fill_manual(values = color_vector)

# %%
ggplot(diff.analysis.sig.plot, aes(x = contrasts, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7,
                     colour="black") +
    labs(y= "\n IS", x = "", title = "Outgoing Signals") +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
          legend.position = "right") + 
         coord_flip()+
    facet_nested(rows = vars(compartment.source, source), 
             scales = "free", space = "free")+
  scale_fill_manual(values = color_vector)
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=12)
grid.arrange(gg2, gg1, nrow = 1)
# Out:
# plot without title

# %%
colnames(diff.analysis.sig.plot)
# Out:
#  [1] "ligand"                        "interaction.id"                "source"                        "target"                        "receptor"                      "obs.contrast1.condition"       "obs.contrast2.condition"       "contrasts"                     "obs.contrast1.FDR"             "obs.contrast2.FDR"             "obs.contrast1.prob"            "obs.contrast2.prob"            "diff.obs"                      "contrast.pvalue"               "stars"                         "Type"                          "Mode.of.Action"                "Functional.classification"     "Functional.sub.classification" "Gene.Family"                   "contrast.FDR"                  "compartment.source"            "compartment.target"            "Interaction.type"              "obs.contrast1.prob.fc"         "obs.contrast2.prob.fc"         "foldchange"                    "direction"

# %%
filter(diff.analysis.sig.plot, source == "Acinar_3" & 
                                ligand == "PRSS1") %>% 
      select(interaction.id, contrasts, diff.obs, obs.contrast1.prob, obs.contrast2.prob)
# Out:
#   interaction.id                             contrasts      diff.obs      obs.contrast1.prob obs.contrast2.prob
# 1 Acinar_3--MUC5b_Ductal--PRSS1--PARD3       Aab.Vs.ND      -0.0549365316  0.0000000000      0.054936532
# 2 Acinar_3--Activated_Stellate--PRSS1--F2RL2 Aab.Vs.ND       0.0001660880  0.0001660880      0.000000000
# 3 Acinar_3--MUC5b_Ductal--PRSS1--F2RL1       T1D_late.Vs.ND -0.0043093650  0.0000000000      0.004309365
# 4 Acinar_3--MUC5b_Ductal--PRSS1--PARD3       T1D_late.Vs.ND -0.0549365316  0.0000000000      0.054936532
# 5 Acinar_3--Acinar_3--PRSS1--F2RL1           Aab.Vs.ND       0.0003015719  0.0003015719      0.000000000
# 6 Acinar_3--Beta--PRSS1--F2RL3               T1D_late.Vs.ND  0.0004567414  0.0004567414      0.000000000
# 7 Acinar_3--Ductal--PRSS1--F2RL1             T1D_late.Vs.ND -0.0012457174 -0.0002549814      0.001500699

# %% [markdown]
# ## IS

# %%
# switiching to aggregate diff.obs from obs.contrast1.prob

# %%
# Perform the aggregation
aggregated_data <- aggregate(diff.obs ~ target + ligand + contrasts + direction + Functional.classification, diff.analysis.sig, sum)
colnames(aggregated_data)[1] = "Celltype"
# Add compartment
aggregated_data = merge(Cellpop.compartment, aggregated_data, by = "Celltype")
# factorize stuff
aggregated_data$compartment = factor(aggregated_data$compartment, levels = unique(compartment))
aggregated_data$Celltype = factor(aggregated_data$Celltype, levels = cell.pop.order)
# Make downregulated data become "-"
# aggregated_data$obs.contrast1.prob[aggregated_data$direction == "DOWN"] <- -aggregated_data$obs.contrast1.prob[aggregated_data$direction == "DOWN"]

# %%
## Optional: Subset to remove categories
aggregated_data = filter(aggregated_data,
                               Functional.classification != "ECM Proteins" &
                               Functional.classification != "Cell Adhesion Molecule" &
                               Functional.classification != "Modulators"                         
                        )

# %%
# This happens when ND is > 0 but the contrast is 0
nrow(aggregated_data)
#aggregated_data = filter(aggregated_data, obs.contrast1.prob != 0)
nrow(aggregated_data)
sum(aggregated_data$diff.obs[aggregated_data$diff.obs >0 ])
sum(aggregated_data$diff.obs[aggregated_data$diff.obs <0 ])
# Out:
# [1] 1439
# [1] 1439
# [1] 1.612803
# [1] -3.363181

# %%
gg1 = ggplot(aggregated_data, aes(x = contrasts, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7,
                     colour="black", size = 0.5) +
    labs(y= "\n Delta - IS (vs ND)", x = "", title = "Incoming Signals") +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
          legend.position = "") + 
         coord_flip()+
    facet_nested(rows = vars(compartment, Celltype), 
             scales = "free", space = "free") +
  scale_fill_manual(values = color_vector)
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”

# %%
# Perform the aggregation
aggregated_data <- aggregate(diff.obs ~ source + ligand + contrasts + direction + Functional.classification, diff.analysis.sig, sum)
colnames(aggregated_data)[1] = "Celltype"
# Add compartment
aggregated_data = merge(Cellpop.compartment, aggregated_data, by = "Celltype")
# factorize stuff
aggregated_data$compartment = factor(aggregated_data$compartment, levels = unique(compartment))
aggregated_data$Celltype = factor(aggregated_data$Celltype, levels = cell.pop.order)
# Make downregulated data become "-"
#aggregated_data$obs.contrast1.prob[aggregated_data$direction == "DOWN"] <- -aggregated_data$obs.contrast1.prob[aggregated_data$direction == "DOWN"]

# %%
## Optional: Subset to remove categories
aggregated_data = filter(aggregated_data,
                               Functional.classification != "ECM Proteins" &
                               Functional.classification != "Cell Adhesion Molecule" &
                               Functional.classification != "Modulators"                         
                        )

# %%
# This happens when ND is > 0 but the contrast is 0
nrow(aggregated_data)
#aggregated_data = filter(aggregated_data, obs.contrast1.prob != 0)
nrow(aggregated_data)
sum(aggregated_data$diff.obs[aggregated_data$diff.obs >0 ])
sum(aggregated_data$diff.obs[aggregated_data$diff.obs <0 ])
# Out:
# [1] 822
# [1] 822
# [1] 1.612803
# [1] -3.363181

# %%
gg2 = ggplot(aggregated_data, aes(x = contrasts, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7,
                     colour="black", size = 0.5) +
    labs(y= "\n Delta - IS (vs ND)", x = "", title = "Outgoing Signals") +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
          legend.position = "") + 
         coord_flip()+
    facet_nested(rows = vars(compartment, Celltype), 
             scales = "free", space = "free")+
  scale_fill_manual(values = color_vector)

# %%
# Plot to check if legend is the same and steal it
ggplot(aggregated_data, aes(x = contrasts, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7,
                     colour="black", size = 0.5) +
    labs(y= "\n IS", x = "", title = "Outgoing Signals") +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", , hjust = 0.5),
          legend.position = "bottom") + 
         coord_flip()+
    facet_nested(rows = vars(compartment, Celltype), 
             scales = "free", space = "free")+
  scale_fill_manual(values = color_vector)
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=12)
grid.arrange(gg2, gg1, nrow = 1)
# Out:
# plot without title

# %%
test = filter(aggregated_data, Celltype == "Acinar_5" & 
                                contrasts == "T1D_late.Vs.ND") %>% 
      select(Celltype, ligand, contrasts, diff.obs)
sum(test$diff.obs[test$diff.obs >0 ])
sum(test$diff.obs[test$diff.obs <0 ])
# Out:
# [1] 0.03080447
# [1] -0.542122

# %% [markdown]
# ## Zoom to one celltype

# %%
cell.pop.order
# Out:
#  [1] "Alpha"              "Beta"               "Delta"              "Acinar1_2_6"        "Acinar_3"           "Acinar_4"           "Acinar_5"           "Ductal"             "MUC5b_Ductal"       "Tcells"             "Macrophage"         "Endothelial"        "Activated_Stellate" "Quiescent_Stellate"

# %%
#obs.contrast1.prob
#diff.obs

# %%
cell.interest = "Beta"
x = 10

# %%
mat = filter(diff.analysis.sig.plot,
             target == cell.interest)

# %%
## Optional: Subset to remove categories
mat = dplyr::filter(diff.analysis.sig.plot,
             target == cell.interest,
             Functional.classification != "ECM Proteins" &
             Functional.classification != "Cell Adhesion Molecule" &
             Functional.classification != "Modulators")

nrow(diff.analysis.sig.plot)
nrow(mat)
# Out:
# [1] 6042
# [1] 276

# %%
# keep strongest Ligand (don't care about which receptor or source)
# Label top incoming signals (top x)

top <- mat %>%
  dplyr::filter(direction == "UP") %>% 
  dplyr::group_by(contrasts) %>% 
  dplyr::arrange(desc(diff.obs)) %>%
  dplyr::distinct(ligand, .keep_all = TRUE) %>% 
  dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  dplyr::filter(label != "")%>%
  ungroup()

bottom <- mat %>%
  dplyr::filter(direction == "DOWN") %>% 
  dplyr::group_by(contrasts) %>% 
  dplyr::arrange(diff.obs) %>%
  dplyr::distinct(ligand, .keep_all = TRUE) %>% 
  dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  dplyr::filter(label != "")%>%
  ungroup()

plot.data = rbind(top, bottom)

plot.data$contrasts = factor(plot.data$contrasts, levels = rev(c('T1D_late.Vs.ND', 
                                                                             'T1D_early.Vs.ND', 'Aab.Vs.ND')))

plot.data.use = dplyr::filter(plot.data, contrasts == 'Aab.Vs.ND')

gg1 = ggplot(plot.data.use, aes(x = reorder(interaction.id, +diff.obs), y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts, direction), 
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)

plot.data.use = dplyr::filter(plot.data, contrasts == 'T1D_early.Vs.ND')

gg2 = ggplot(plot.data.use, aes(x = reorder(interaction.id, +diff.obs), y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts, direction),  
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)


plot.data.use = dplyr::filter(plot.data, contrasts == 'T1D_late.Vs.ND')

gg3 = ggplot(plot.data.use, aes(x = reorder(interaction.id, +diff.obs), y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts, direction), 
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)

# %%
options(repr.plot.width=12, repr.plot.height=22)
grid.arrange(gg1, gg2, gg3, nrow = 3)
# Out:
# plot without title

# %%
mat = filter(diff.analysis.sig.plot,
             source == cell.interest)

# %%
## Optional: Subset to remove categories
mat = filter(diff.analysis.sig.plot,
             source == cell.interest,
             Functional.classification != "ECM Proteins" &
             Functional.classification != "Cell Adhesion Molecule" &
             Functional.classification != "Modulators"                         
                        )
nrow(diff.analysis.sig.plot)
nrow(mat)
# Out:
# [1] 6042
# [1] 324

# %%
# keep strongest Ligand (don't care about which receptor or source)
# Label top incoming signals (top x)

top <- mat %>%
  dplyr::filter(direction == "UP") %>% 
  dplyr::group_by(contrasts) %>% 
  dplyr::arrange(desc(diff.obs)) %>%
  dplyr::distinct(ligand, .keep_all = TRUE) %>% 
  dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  dplyr::filter(label != "")%>%
  ungroup()

bottom <- mat %>%
  dplyr::filter(direction == "DOWN") %>% 
  dplyr::group_by(contrasts) %>% 
  dplyr::arrange(diff.obs) %>%
  dplyr::distinct(ligand, .keep_all = TRUE) %>% 
  dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  dplyr::filter(label != "")%>%
  ungroup()

plot.data = rbind(top, bottom)

plot.data$contrasts = factor(plot.data$contrasts, levels = rev(c('T1D_late.Vs.ND', 
                                                                             'T1D_early.Vs.ND', 'Aab.Vs.ND')))

plot.data.use = filter(plot.data, contrasts == 'Aab.Vs.ND')

gg1 = ggplot(plot.data.use, aes(x = reorder(interaction.id, +diff.obs), y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts, direction), 
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)

plot.data.use = filter(plot.data, contrasts == 'T1D_early.Vs.ND')

gg2 = ggplot(plot.data.use, aes(x = reorder(interaction.id, +diff.obs), y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts, direction),  
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)


plot.data.use = filter(plot.data, contrasts == 'T1D_late.Vs.ND')

gg3 = ggplot(plot.data.use, aes(x = reorder(interaction.id, +diff.obs), y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts, direction), 
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)

# %%
options(repr.plot.width=12, repr.plot.height=22)
grid.arrange(gg1, gg2, gg3, nrow = 3)
# Out:
# plot without title

# %%
# Perform the aggregation
aggregated_data <- aggregate(diff.obs ~ target + ligand + contrasts + direction + Functional.classification, diff.analysis.sig, sum)
colnames(aggregated_data)[1] = "Celltype"
# Add compartment
aggregated_data = merge(Cellpop.compartment, aggregated_data, by = "Celltype")
# factorize stuff
aggregated_data$compartment = factor(aggregated_data$compartment, levels = unique(compartment))
aggregated_data$Celltype = factor(aggregated_data$Celltype, levels = cell.pop.order)
# Make downregulated data become "-"
#aggregated_data$obs.contrast1.prob[aggregated_data$direction == "DOWN"] <- -aggregated_data$obs.contrast1.prob[aggregated_data$direction == "DOWN"]

# %%
## Optional: Subset to remove categories
aggregated_data = filter(aggregated_data,
                               Functional.classification != "ECM Proteins" &
                               Functional.classification != "Cell Adhesion Molecule" &
                               Functional.classification != "Modulators"                         
                        )

# %%
aggregated_data = filter(aggregated_data, Celltype == cell.interest)
aggregated_data$contrasts = factor(aggregated_data$contrasts, levels = rev(c('T1D_late.Vs.ND', 
                                                                             'T1D_early.Vs.ND', 'Aab.Vs.ND')))

# %%
#nrow(aggregated_data)
#aggregated_data = filter(aggregated_data, obs.contrast1.prob != 0)
#nrow(aggregated_data)

# %%
# Label top incoming signals (top x)
x = 3

top <- aggregated_data %>%
                    dplyr::group_by(contrasts) %>% 
  dplyr::arrange(desc(obs.contrast1.prob)) %>%
  dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  dplyr::filter(label != "")%>%
  ungroup()

bottom <- aggregated_data %>%
                    dplyr::group_by(contrasts) %>% 
  dplyr::arrange(obs.contrast1.prob) %>%
  dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  dplyr::filter(label != "")%>%
  ungroup()

plot.data = rbind(top, bottom)
# Out:
# Error in `dplyr::arrange()`:
# ℹ In argument: `..1 = obs.contrast1.prob`.
# Caused by error:
# ! object 'obs.contrast1.prob' not found
# Traceback:
#
# 1. aggregated_data %>% dplyr::group_by(contrasts) %>% dplyr::arrange(desc(obs.contrast1.prob)) %>%
#  .     dplyr::mutate(label = ifelse(row_number() <= x, as.character(ligand),
#  .         "")) %>% dplyr::filter(label != "") %>% ungroup()
# 2. ungroup(.)
# 3. dplyr::filter(., label != "")
# 4. dplyr::mutate(., label = ifelse(row_number() <= x, as.character(ligand),
#  .     ""))
# 5. dplyr::arrange(., desc(obs.contrast1.prob))
# 6. arrange.data.frame(., desc(obs.contrast1.prob))
# 7. arrange_rows(.data, dots = dots, locale = .locale)
# 8. mutate(data, `:=`("{name}", !!dot), .keep = "none")
# 9. mutate.data.frame(data, `:=`("{name}", !!dot), .keep = "none")
# 10. mutate_cols(.data, dplyr_quosures(...), by)
# 11. withCallingHandlers(for (i in seq_along(dots)) {
#   .     poke_error_context(dots, i, mask = mask)
#   .     context_poke("column", old_current_column)
#   .     new_columns <- mutate_col(dots[[i]], data, mask, new_columns)
#   . }, error = dplyr_error_handler(dots = dots, mask = mask, bullets = mutate_bullets,
#   .     error_call = error_call, error_class = "dplyr:::mutate_error"),
#   .     warning = dplyr_warning_handler(state = warnings_state, mask = mask,
#   .         error_call = error_call))
# 12. mutate_col(dots[[i]], data, mask, new_columns)
# 13. mask$eval_all_mutate(quo)
# 14. eval()
# 15. .handleSimpleError(function (cnd)
#   . {
#   .     local_error_context(dots, i = frame[[i_sym]], mask = mask)
#   .     if (inherits(cnd, "dplyr:::internal_error")) {
#   .         parent <- error_cnd(message = bullets(cnd))
#   .     }
#   .     else {
#   .         parent <- cnd
#   .     }
#   .     message <- c(cnd_bullet_header(action), i = if (has_active_group_context(mask)) cnd_bullet_cur_group_label())
#   .     abort(message, class = error_class, parent = parent, call = error_call)
#   . }, "object 'obs.contrast1.prob' not found", base::quote(eval()))
# 16. h(simpleError(msg, call))
# 17. abort(message, class = error_class, parent = parent, call = error_call)
# 18. signal_abort(cnd, .file)

# %%
# Label top incoming signals (top x)
x = 3

top <- aggregated_data %>%
                    group_by(contrasts) %>% 
  arrange(desc(diff.obs)) %>%
  mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  filter(label != "")%>%
  ungroup()

bottom <- aggregated_data %>%
                    group_by(contrasts) %>% 
  arrange(diff.obs) %>%
  mutate(label = ifelse(row_number() <= x, as.character(ligand), "")) %>%
  filter(label != "")%>%
  ungroup()

plot.data = rbind(top, bottom)

# %%
plot.data.use = filter(plot.data, direction == "UP")

gg1 = ggplot(plot.data.use, aes(x = ligand, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "Incoming Signals", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts), 
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)

# %%
plot.data.use = filter(plot.data, direction == "DOWN")

gg2 = ggplot(plot.data.use, aes(x = ligand, y = diff.obs, fill = Functional.classification)) +
    geom_bar(stat="identity", width = 0.7, colour="black") +
    labs(y= "\n DELTA - IS", x = "", title = "Incoming Signals", position = position_dodge()) +
    theme_bw() +
    theme(axis.text = element_text(size = 16),
          axis.title = element_text(size = 12, face = "bold"), 
          plot.title = element_text(size = 18, face = "bold", hjust = 0.5),
          axis.text.x = element_text(angle = 45, hjust = 1),
          legend.position = "") + 
    coord_flip() +
    facet_nested(cols = vars(contrasts), 
                 scales = "free", space = "fixed")+
  scale_fill_manual(values = color_vector)

# %%
options(repr.plot.width=12, repr.plot.height=8)
grid.arrange(gg2, gg1, nrow = 1)
